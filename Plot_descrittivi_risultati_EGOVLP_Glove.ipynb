# %%
# @title Monta il drive su colab
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# @title Setup Librerie
import os
import json
import glob
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
# @title Definizione dei path
# Path per accedere ai risultati sul validation set di VSLNet + EGOVLP
# Path per accedere al training con remove empy from train + val
# pred_dir_vslnet = "/content/drive/MyDrive/training/training_best_200_GLOVE_vslnet_egovlp/egovlp_fp16/vslnet_nlq_official_v1_egovlp_fp16_official_128_glove/model/"
# Path per accedere al training con remove empy from train
pred_dir_vslnet = "/content/drive/MyDrive/training_best_200_GLOVE_vslnet_egovlp_onlytrain/egovlp_fp16/vslnet_nlq_official_v1_egovlp_fp16_official_128_glove/model/"
# Path per accedere ai risultati sul validation set di VSLBase + EGO VLP
pred_dir_vslbase = "/content/drive/MyDrive/training/training_best_200_GLOVE_vslbase_egovlp/checkpoints/egovlp_fp16/vslbase_nlq_official_v1_egovlp_fp16_official_128_glove/model/"
# Path per accedere ai ground truth sul dataset di validazione
gt_path = "/content/drive/MyDrive/backup_colab/content/ego4d_data/v1/annotations/nlq_val.json"
# Path per salvare i risultati
output_dir = "/content/drive/MyDrive/Risultati/VSL+EGOVLP/Glove/"
os.makedirs(output_dir, exist_ok=True)

# Percorso del file delle short queries
short_queries_path = "/content/drive/MyDrive/Risultati/short_queries_val.json"

# Carica le short queries
with open(short_queries_path) as f:
    short_queries = json.load(f)

# Costruisci il set dei bad_keys (tuple)
bad_keys = {
    (q["clip_uid"], q["annotation_uid"], q["query_idx"])
    for q in short_queries
}

# %% [markdown]
# SPIEGAZIONE STEP SUCCESSIVI
#
# METRICA INTERSECTION OVER UNION (IoU/ Jaccard similarity/ Jaccard Index) \\
# DEF: IoU =  $\frac{\text{Area of intersection}}{\text{Area over Union}}$ \\
# IoU $\geq$ 0.5 is "decent" \\
# IoU $\geq$ 0.7 is "pretty good" \\
# IoU $\geq$ 0.9 is "almost perfect" \\
#
#
# Per selezionare il .json file migliore, si usa il criterio Rank@1 IoU@0.5 ->
# Ti dice quante volte la prima predizione (top-1) del modello ha un'IoU ≥ 0.3 rispetto al segmento annotato (ground truth).
# NOTA: Lo 0.3 è un compromesso classico tra tolleranza e precisione, usato anche in altri task di detection
# Operativamente, viene selezionato il j.son file che ha quanti più clip con primo intervallo di previsione con IoU >0.3

# %%
# @title Funzioni per i plot
# Funzione per il calcolo della metrica IoU (versione vecchia)
# def compute_iou(s1, e1, s2, e2):
##    inter = max(0, min(e1, e2) - max(s1, s2))
#    union = max(e1, e2) - min(s1, s2)
#    return inter / (union + 1e-6)


# Funzione che calcola IoU (versione più corretta)
def compute_iou(s1, e1, s2, e2):
    # calcolo intersezione
    inter = max(0, min(e1, e2) - max(s1, s2))

    # calcolo area di ciascun segmento
    area1 = max(0, e1 - s1)
    area2 = max(0, e2 - s2)

    # union corretta
    union = area1 + area2 - inter

    return inter / (union + 1e-6)

# Funzione per costruzione dizionario per ground truth
def load_gt(gt_path):
  # Apro .json file con le annotazioni sul valitation
    with open(gt_path) as f:
        ann_data = json.load(f)
    # Inizializzo un dizionario vuoto
    gt_lookup = {}
    # Per ogni video nel file di annotazione
    for video in ann_data["videos"]:
      # Per ogni clip corrispondente a un video nel file
        for clip in video["clips"]:
          # Salvo l'identificativo del clip
            clip_uid = clip["clip_uid"]
            # Per ogni annotazione in un clip
            for annotation in clip["annotations"]:
              # Salvo l'identificativo dell'annotazione
                annotation_uid = annotation["annotation_uid"]
                # Per ogni query contenute nell'elenco language_queries
                for query_idx, query in enumerate(annotation.get("language_queries", [])):
                    if "query" not in query:
                        continue
                    # Definisco la chiave identificativa del dizionario, coincidente con id del clip, id della annotazione, indice della query
                    key = (clip_uid, annotation_uid, query_idx)
                    # Salvo le informazioni d'interesse
                    gt_lookup[key] = {
                        # Salvo video_uid per risalire al video e fare eventuali plot
                        "video_uid": video["video_uid"],
                        # gt_start è l'inizio del ground truth per la query d'interesse
                        "gt_start": query["clip_start_sec"],
                        # gt_end è la fine del ground truth per la query d'interesse
                        "gt_end": query["clip_end_sec"],
                        # query è proprio la domanda che viene formulata
                        "query": query["query"],
                         # template è il tipo di domanda che viene fatta
                        "template": query["template"],
                        # è l'istante di inizio della clip considerata, rispetto all'interezza del video, MA NON DOVREBBE SERVIRE
                        "clip_start_sec": clip["video_start_sec"]
                    }
    return gt_lookup

# Funzione per selezionare il .json file migliore, secondo la metrica RANK@1 IoU@0.3 (ma per come è formulata è facile cambiare metrica se si vuole ad esempio RANK#5 IoU@0.5)
def evaluate_predictions(pred_dir, gt_lookup, top_k=[1, 5], iou_thr=0.3):
    best_file = None             # File .json con le predizioni migliori
    best_recall = -1             # Miglior valore di recall osservato finora
    json_files = sorted(glob.glob(os.path.join(pred_dir, "*.json")))  # Tutti i file .json salvati

    # Cicla su tutti i .json file (ogni file rappresenta un checkpoint di un modello: epoca+iterazione)
    for file in json_files:
        try:
            # Carica le predizioni da file (contenute dentro l'item results)
            with open(file) as f:
                pred_data = json.load(f)["results"]
            tmp_records = []

            # Cicla su ogni previsione nel file
            for item in pred_data:
              # Definisco la chiave univoca che caratterizza ogni previsione (analoga a gt_lookup)
                key = (item["clip_uid"], item["annotation_uid"], item["query_idx"])

                # Se non c'è il ground truth per questa tripla oppure non ci sono predizioni, salta
                if key not in gt_lookup or not item.get("predicted_times"):
                    continue

                gt = gt_lookup[key]                     # Ground truth segment
                #clip_start = gt["clip_start_sec"]       # Inizio del clip (per correggere i tempi)
                # Inizializzo una lista che contenga gli ious di ogni previsione per ogni file
                ious = []

                # Ciclo sulle 5 predizioni di una data query
                for i in range(min(len(item["predicted_times"]), max(top_k))):
                    # Memorizzo gli istanti di inizio e fine predetti nell'i-esima previsione, sono gli istanti rispetto al VIDEO, proprio come le info memorizzate nel GT
                    pred_start, pred_end = item["predicted_times"][i]

                    # Calcola l’IoU tra predizione e ground truth
                    iou = compute_iou(pred_start, pred_end, gt["gt_start"], gt["gt_end"])
                    # Aggiungo l'iou calcolato alla lista
                    ious.append(iou)

                # Salva solo la iou@1 (cioè quella della prima predizione)
                tmp_records.append({f"iou@1": ious[0]})

            # Costruisce un DataFrame con tutte le iou@1 e calcola il recall = % di predizioni con iou >= soglia
            tmp_df = pd.DataFrame(tmp_records)
            recall = (tmp_df["iou@1"] >= iou_thr).mean()  # ≈ Rank@1@0.5

            # Se è il miglior risultato visto finora, aggiorna
            if recall > best_recall:
                best_recall = recall
                best_file = file
        except:
            continue  # In caso di errore nel file, va avanti
    return best_file  # Ritorna il file con il miglior Rank@1@0.5 (approssimato come recall)

# Funzione per costruire un dataframe con tutte le informazioni utili per ogni query
# INPUTS:
# pred_file = .json file riferito all'epoca+iterazione migliore secondo la metrica Rank@1 IoU@0.3 ottenuto dalla funzione precedente. presenta dato un clip_uid, annotation_uid, query_idx 5 predicted times
# gt_lookup = dizionario avente chiave identificativa (clip_uid, annotation_uid, query_idx) in maniera conforme alle informazioni contenute nel .json file, ottenuto dalla funzione load_gt.
# Contiene template, query, gt_start e gt_end come informazioni di interesse

# OUTPUT:
# Restituisce un dataframe che per ogni (clip_uid, annotation_uid, query_idx) restituisce query, template della query, istanti predetti e gt, window_length

def build_dataframe(pred_file, gt_lookup, top_k=[1, 5]):
    # Apro il .json file con le previsioni
    with open(pred_file) as f:
        pred_data = json.load(f)["results"]
    # Inizializzo il dataframe
    records = []
    # Scorro dentro il file con le previsioni
    for item in pred_data:
        # Memorizzo in key le informazioni univoche che caratterizzano la query predetta
        key = (item["clip_uid"], item["annotation_uid"], item["query_idx"])
        # Controllo che esiste una query corrispondente nel dizionario di gt e che per quella query ci sia l'item predicted_times
        if key not in gt_lookup or not item.get("predicted_times"):
            continue
        # Accedo alla query nel file di gt
        gt = gt_lookup[key]
        # Inizializzo lista con ious
        ious = []
        # Ciclo sulle i previsioni fornite nel .json file per ogni query
        for i in range(min(len(item["predicted_times"]), max(top_k))):
            # Salvo tempo di inizio e tempo di file per la query corrispondenti alla previsione i
            pred_start, pred_end = item["predicted_times"][i]
            # Calcolo la iou
            iou = compute_iou(pred_start, pred_end, gt["gt_start"], gt["gt_end"])
            # Aggiungo la iou alla lista
            ious.append(iou)
        # Salvo le informazioni
        records.append({
             # IDENTIFICATIVI DELLA QUERY
            "clip_uid": item["clip_uid"], # Add clip_uid to the dataframe
            "annotation_uid": item["annotation_uid"], # Add annotation_uid to the dataframe
            "query_idx": item["query_idx"], # Add query_idx to the dataframe
             # Salvo video_uid per risalire al video di appartenenza della query quando facciamo i plot
             "video_uid": gt["video_uid"],
             # Salvo il template della query per verificare se ci sono template più problematici di altri
             "template": gt["template"],
            "query": gt["query"],
            "gt_start": gt["gt_start"],
            "gt_end": gt["gt_end"],
            # pred_start è il primo istante (su 5) predetto come tempo iniziale per rispondere alla query di interesse
            "pred_start": item["predicted_times"][0][0],
            # pred_end è il primo istante (su 5) predetto come tempo finale per rispondere alla query di interesse
            "pred_end": item["predicted_times"][0][1],
            # iou calcolata in base alla prima previsione per quella query
            "iou": ious[0],
            # Per ogni valore k in top_k (es. [1, 5]): prende le prime k previsioni (ious[:k]) calcola la migliore IoU tra le prime k predizioni, se ci sono meno di k previsioni, mette 0.0
            **{f"iou@{k}": max(ious[:k]) if len(ious) >= k else 0.0 for k in top_k}
        })
    # Costruisco dataframe
    df = pd.DataFrame(records)
    # Creo una nuova colonna chiamata gt_len, ovvero la lunghezza dell'intervallo gt
    df["gt_len"] = df["gt_end"] - df["gt_start"]
    # Creo una nuova colonna chiamata gt_len, ovvero la lunghezza dell'intervallo predetto
    df["pred_len"] = df["pred_end"] - df["pred_start"]
    # Creo una nuova colonna chiamata length_error contentente la differenza, ovvero moment_length_errorr
    df["length_error"] = df["pred_len"] - df["gt_len"]
    return df

# Funzione per l' istogramma IoU
def plot_iou_histogram_comparison(df1, df2, label1, label2, output_path_base, bins=10, alpha=0.7):
    """
    Crea due istogrammi comparativi dell'IoU tra df1 e df2:
    1. Inclusi tutti gli intervalli [0.0, 1.0]
    2. Escludendo l'intervallo [0.0, 0.1)

    Salva entrambe le figure nella cartella di output_path_base, usando come base il nome file.
    """
    # Estraggo directory e filename base
    output_dir = os.path.dirname(output_path_base)
    base_filename = os.path.splitext(os.path.basename(output_path_base))[0]
    os.makedirs(output_dir, exist_ok=True)
    # Funzione che realmente costruisce l'istogramma
    def plot_single_histogram(data1, data2, bin_edges, suffix):
        bin_width = bin_edges[1] - bin_edges[0]
        counts1, _ = np.histogram(data1["iou"], bins=bin_edges)
        counts2, _ = np.histogram(data2["iou"], bins=bin_edges)

        plt.figure(figsize=(10, 6))
        plt.bar(
            bin_edges[:-1], counts1, width=bin_width,
            align='edge', alpha=alpha, label=label1,
            edgecolor='black', linewidth=1.2, color='royalblue'
        )
        plt.bar(
            bin_edges[:-1], counts2, width=bin_width,
            align='edge', alpha=alpha, label=label2,
            edgecolor='black', linewidth=1.2, color='salmon'
        )

        plt.xlabel("Intersection over Union (IoU)", fontsize=14)
        plt.ylabel("# of Samples", fontsize=14)
        plt.xticks(bin_edges, [f"{x:.1f}" for x in bin_edges])
        plt.legend(fontsize=12)
        plt.grid(axis='y', linestyle='--', alpha=0.5)
        plt.tight_layout()

        output_file = os.path.join(output_dir, f"{base_filename}_{suffix}.png")
        plt.savefig(output_file)
        plt.show()

    # Primo plot: tutti gli intervalli da 0.0 a 1.0
    bin_edges_all = np.linspace(0, 1, bins + 1)
    plot_single_histogram(df1, df2, bin_edges_all, "with_0.0")

    # Secondo plot: da 0.1 a 1.0, escludendo il primo intervallo
    bin_edges_cut = np.linspace(0.1, 1, bins)
    plot_single_histogram(df1[df1["iou"] >= 0.1],
                          df2[df2["iou"] >= 0.1],
                          bin_edges_cut, "without_0.0")



# Funzione che plotta Moment Lenght Error tra VSLBase e VSLNet OK
def plot_length_error_comparison_lines(df1, df2, label1, label2, output_path, bins=30):
    counts1, bin_edges = np.histogram(df1["length_error"], bins=bins)
    counts2, _ = np.histogram(df2["length_error"], bins=bin_edges)

    # Calcola i centri dei bin per tracciare la linea
    bin_centers = (bin_edges[:-1] + bin_edges[1:]) / 2

    plt.figure(figsize=(8,5))
    plt.plot(bin_centers, counts1, label=label1, color='blue', marker='o')
    plt.plot(bin_centers, counts2, label=label2, color='red', marker='o')
    plt.axvline(0, color='black', linestyle='--')
    plt.xlabel("Moment Length Error (seconds)")
    plt.ylabel("# of Samples")
    plt.title("Moment Length Error Comparison")
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.savefig(output_path)
    plt.show()


# Seleziono 5 casi significativi
def seleziona_casi_specifici(df_base, df_net):
    df_base = df_base.copy()
    df_net = df_net.copy()

    # Usa la chiave composta da clip_uid, annotation_uid, query_idx per il merge
    df_base["key"] = list(zip(df_base["clip_uid"], df_base["annotation_uid"], df_base["query_idx"]))
    df_net["key"] = list(zip(df_net["clip_uid"], df_net["annotation_uid"], df_net["query_idx"]))

    # Merge su "key"
    merged = pd.merge(df_net, df_base, on="key", suffixes=("_net", "_base"))

    # 1. Miglior caso per VSLNet
    best_net_row = merged.loc[merged["iou_net"].idxmax()]

    # 2. Miglior caso per VSLBase
    best_base_row = merged.loc[merged["iou_base"].idxmax()]

    # 3. Peggior caso per VSLNet
    worst_net_row = merged.loc[merged["iou_net"].idxmin()]

    # 4. Peggior caso per VSLBase
    worst_base_row = merged.loc[merged["iou_base"].idxmin()]

    # 5. Caso in cui VSLNet è molto meglio del Base
    merged["diff_net_base"] = merged["iou_net"] - merged["iou_base"]
    net_better_row = merged.loc[merged["diff_net_base"].idxmax()]

    return {
        "best_net": best_net_row,
        "best_base": best_base_row,
        "worst_net": worst_net_row,
        "worst_base": worst_base_row,
        "net_better": net_better_row
    }
# Funzione per fare il grafico dei 5 casi significativi
def plot_cinque_casi_riformattato(casi_dict, output_path):
    casi_labels = {
        "best_net": "Best VSLNet",
        "best_base": "Best VSLBase",
        "worst_net": "Worst VSLNet",
        "worst_base": "Worst VSLBase",
        "net_better": "VSLNet >> VSLBase"
    }

    colors = {"GT": "green", "VSLBase": "gold", "VSLNet": "skyblue"}

    fig, axs = plt.subplots(5, 1, figsize=(12, 10), sharex=False)

    for i, (key, row) in enumerate(casi_dict.items()):
        gt_start = row["gt_start_net"] if "gt_start_net" in row else row["gt_start"]
        gt_end = row["gt_end_net"] if "gt_end_net" in row else row["gt_end"]

        axs[i].hlines(3, gt_start, gt_end, color=colors["GT"], linewidth=5, label="GT")
        axs[i].hlines(2, row["pred_start_base"], row["pred_end_base"], color=colors["VSLBase"], linewidth=5, label="VSLBase")
        axs[i].hlines(1, row["pred_start_net"], row["pred_end_net"], color=colors["VSLNet"], linewidth=5, label="VSLNet")

        axs[i].set_yticks([1, 2, 3])
        axs[i].set_yticklabels(["VSLNet", "VSLBase", "GT"])
        axs[i].set_title(f"{casi_labels[key]}\nQuery: {row['query_net'][:100]}", fontsize=10, loc="left")
        axs[i].grid(True, axis="x", linestyle="--", alpha=0.4)
        axs[i].spines[['top','right','left']].set_visible(False)

    # Sposto la legenda fuori dal grafico, a destra
    axs[0].legend(loc="center left", bbox_to_anchor=(1, 0.5))

    plt.xlabel("Time (s)")
    plt.tight_layout()
    plt.savefig(output_path)
    plt.show()

# Funzione per tabella riepilogativa per confronto con Slow Fast
def build_results_table(data_list, output_path):
    rows = []
    for df, model_name, feature_name in data_list:
        row = [
            model_name,
            feature_name,
            f"{(df['iou@1'] >= 0.3).mean() * 100:.2f}",
            f"{(df['iou@5'] >= 0.3).mean() * 100:.2f}",
            f"{(df['iou@1'] >= 0.5).mean() * 100:.2f}",
            f"{(df['iou@5'] >= 0.5).mean() * 100:.2f}",
        ]
        rows.append(row)

    # Aggiungi baseline
    rows.append(["VSLNet", "FastFeatures", "5.65", "10.76", "3.12", "6.63"])

    col_labels = [
        "Modello", "Feature Extractor",
        "IoU=0.3\nR@1", "IoU=0.3\nR@5",
        "IoU=0.5\nR@1", "IoU=0.5\nR@5"
    ]

    fig, ax = plt.subplots(figsize=(11, 0.6 + len(rows) * 0.6))
    ax.axis('off')

    table = ax.table(
        cellText=rows,
        colLabels=col_labels,
        cellLoc='center',
        loc='center'
    )

    table.auto_set_font_size(False)
    table.set_fontsize(13)
    table.scale(1.6, 1.6)

    plt.title("Performance Riassuntiva - VSL + Feature Extractor", pad=20, fontsize=14)
    plt.tight_layout()
    plt.savefig(output_path)
    plt.show()

# %%
# @ title Correzione dei file nel Drive per VSLBase (PIETRO SEI UN POLLO HAI SALVATO I RISULTATI DI VSLBASE COME VSLNET!!!)
import os
import glob
import shutil

# Cartella contenente i file da correggere
folder_path ="/content/drive/MyDrive/training/training_best_200_GLOVE_vslbase_egovlp/checkpoints/egovlp_fp16/vslbase_nlq_official_v1_egovlp_fp16_official_128_glove/model/"

# Trova tutti i file JSON
json_files = glob.glob(os.path.join(folder_path, "*.json"))

for file_path in json_files:
    file_name = os.path.basename(file_path)
    if file_name.startswith("vslnet_"):
        new_name = file_name.replace("vslnet_", "vslbase_", 1)
        new_path = os.path.join(folder_path, new_name)
        if not os.path.exists(new_path):
            shutil.copy(file_path, new_path)
            print(f"✅ Copiato:\n  {file_name} → {new_name}")
        else:
            print(f"⚠️ Esiste già: {new_name} (niente fatto)")
# Out:
# ✅ Copiato:
#   vslnet_184_118818_preds.json → vslbase_184_118818_preds.json
# ✅ Copiato:
#   vslnet_184_119140_preds.json → vslbase_184_119140_preds.json
# ✅ Copiato:
#   vslnet_0_322_preds.json → vslbase_0_322_preds.json
# ✅ Copiato:
#   vslnet_1_1290_preds.json → vslbase_1_1290_preds.json
# ✅ Copiato:
#   vslnet_0_644_preds.json → vslbase_0_644_preds.json
# ✅ Copiato:
#   vslnet_2_1935_preds.json → vslbase_2_1935_preds.json
# ✅ Copiato:
#   vslnet_0_645_preds.json → vslbase_0_645_preds.json
# ✅ Copiato:
#   vslnet_1_966_preds.json → vslbase_1_966_preds.json
# ✅ Copiato:
#   vslnet_3_2254_preds.json → vslbase_3_2254_preds.json
# ✅ Copiato:
#   vslnet_1_1288_preds.json → vslbase_1_1288_preds.json
# ✅ Copiato:
#   vslnet_3_2576_preds.json → vslbase_3_2576_preds.json
# ✅ Copiato:
#   vslnet_2_1610_preds.json → vslbase_2_1610_preds.json
# ✅ Copiato:
#   vslnet_2_1932_preds.json → vslbase_2_1932_preds.json
# ✅ Copiato:
#   vslnet_4_3220_preds.json → vslbase_4_3220_preds.json
# ✅ Copiato:
#   vslnet_7_4830_preds.json → vslbase_7_4830_preds.json
# ✅ Copiato:
#   vslnet_8_5474_preds.json → vslbase_8_5474_preds.json
# ✅ Copiato:
#   vslnet_3_2580_preds.json → vslbase_3_2580_preds.json
# ✅ Copiato:
#   vslnet_4_2898_preds.json → vslbase_4_2898_preds.json
# ✅ Copiato:
#   vslnet_9_6440_preds.json → vslbase_9_6440_preds.json
# ✅ Copiato:
#   vslnet_4_3225_preds.json → vslbase_4_3225_preds.json
# ✅ Copiato:
#   vslnet_5_3542_preds.json → vslbase_5_3542_preds.json
# ✅ Copiato:
#   vslnet_5_3864_preds.json → vslbase_5_3864_preds.json
# ✅ Copiato:
#   vslnet_5_3870_preds.json → vslbase_5_3870_preds.json
# ✅ Copiato:
#   vslnet_6_4186_preds.json → vslbase_6_4186_preds.json
# ✅ Copiato:
#   vslnet_6_4508_preds.json → vslbase_6_4508_preds.json
# ✅ Copiato:
#   vslnet_6_4515_preds.json → vslbase_6_4515_preds.json
# ✅ Copiato:
#   vslnet_10_7095_preds.json → vslbase_10_7095_preds.json
# ✅ Copiato:
#   vslnet_7_5152_preds.json → vslbase_7_5152_preds.json
# ✅ Copiato:
#   vslnet_7_5160_preds.json → vslbase_7_5160_preds.json
# ✅ Copiato:
#   vslnet_11_7728_preds.json → vslbase_11_7728_preds.json
# ✅ Copiato:
#   vslnet_8_5796_preds.json → vslbase_8_5796_preds.json
# ✅ Copiato:
#   vslnet_8_5805_preds.json → vslbase_8_5805_preds.json
# ✅ Copiato:
#   vslnet_9_6118_preds.json → vslbase_9_6118_preds.json
# ✅ Copiato:
#   vslnet_11_7740_preds.json → vslbase_11_7740_preds.json
# ✅ Copiato:
#   vslnet_9_6450_preds.json → vslbase_9_6450_preds.json
# ✅ Copiato:
#   vslnet_10_6762_preds.json → vslbase_10_6762_preds.json
# ✅ Copiato:
#   vslnet_10_7084_preds.json → vslbase_10_7084_preds.json
# ✅ Copiato:
#   vslnet_14_9675_preds.json → vslbase_14_9675_preds.json
# ✅ Copiato:
#   vslnet_11_7406_preds.json → vslbase_11_7406_preds.json
# ✅ Copiato:
#   vslnet_15_9982_preds.json → vslbase_15_9982_preds.json
# ✅ Copiato:
#   vslnet_19_12880_preds.json → vslbase_19_12880_preds.json
# ✅ Copiato:
#   vslnet_12_8050_preds.json → vslbase_12_8050_preds.json
# ✅ Copiato:
#   vslnet_12_8372_preds.json → vslbase_12_8372_preds.json
# ✅ Copiato:
#   vslnet_12_8385_preds.json → vslbase_12_8385_preds.json
# ✅ Copiato:
#   vslnet_13_8694_preds.json → vslbase_13_8694_preds.json
# ✅ Copiato:
#   vslnet_13_9016_preds.json → vslbase_13_9016_preds.json
# ✅ Copiato:
#   vslnet_13_9030_preds.json → vslbase_13_9030_preds.json
# ✅ Copiato:
#   vslnet_14_9338_preds.json → vslbase_14_9338_preds.json
# ✅ Copiato:
#   vslnet_14_9660_preds.json → vslbase_14_9660_preds.json
# ✅ Copiato:
#   vslnet_19_12900_preds.json → vslbase_19_12900_preds.json
# ✅ Copiato:
#   vslnet_24_16100_preds.json → vslbase_24_16100_preds.json
# ✅ Copiato:
#   vslnet_15_10304_preds.json → vslbase_15_10304_preds.json
# ✅ Copiato:
#   vslnet_15_10320_preds.json → vslbase_15_10320_preds.json
# ✅ Copiato:
#   vslnet_16_10626_preds.json → vslbase_16_10626_preds.json
# ✅ Copiato:
#   vslnet_16_10948_preds.json → vslbase_16_10948_preds.json
# ✅ Copiato:
#   vslnet_16_10965_preds.json → vslbase_16_10965_preds.json
# ✅ Copiato:
#   vslnet_17_11270_preds.json → vslbase_17_11270_preds.json
# ✅ Copiato:
#   vslnet_17_11592_preds.json → vslbase_17_11592_preds.json
# ✅ Copiato:
#   vslnet_17_11610_preds.json → vslbase_17_11610_preds.json
# ✅ Copiato:
#   vslnet_18_11914_preds.json → vslbase_18_11914_preds.json
# ✅ Copiato:
#   vslnet_18_12236_preds.json → vslbase_18_12236_preds.json
# ✅ Copiato:
#   vslnet_18_12255_preds.json → vslbase_18_12255_preds.json
# ✅ Copiato:
#   vslnet_19_12558_preds.json → vslbase_19_12558_preds.json
# ✅ Copiato:
#   vslnet_29_19320_preds.json → vslbase_29_19320_preds.json
# ✅ Copiato:
#   vslnet_30_19964_preds.json → vslbase_30_19964_preds.json
# ✅ Copiato:
#   vslnet_20_13202_preds.json → vslbase_20_13202_preds.json
# ✅ Copiato:
#   vslnet_20_13524_preds.json → vslbase_20_13524_preds.json
# ✅ Copiato:
#   vslnet_20_13545_preds.json → vslbase_20_13545_preds.json
# ✅ Copiato:
#   vslnet_21_13846_preds.json → vslbase_21_13846_preds.json
# ✅ Copiato:
#   vslnet_21_14168_preds.json → vslbase_21_14168_preds.json
# ✅ Copiato:
#   vslnet_21_14190_preds.json → vslbase_21_14190_preds.json
# ✅ Copiato:
#   vslnet_22_14490_preds.json → vslbase_22_14490_preds.json
# ✅ Copiato:
#   vslnet_22_14812_preds.json → vslbase_22_14812_preds.json
# ✅ Copiato:
#   vslnet_22_14835_preds.json → vslbase_22_14835_preds.json
# ✅ Copiato:
#   vslnet_23_15134_preds.json → vslbase_23_15134_preds.json
# ✅ Copiato:
#   vslnet_23_15456_preds.json → vslbase_23_15456_preds.json
# ✅ Copiato:
#   vslnet_23_15480_preds.json → vslbase_23_15480_preds.json
# ✅ Copiato:
#   vslnet_24_15778_preds.json → vslbase_24_15778_preds.json
# ✅ Copiato:
#   vslnet_31_20608_preds.json → vslbase_31_20608_preds.json
# ✅ Copiato:
#   vslnet_24_16125_preds.json → vslbase_24_16125_preds.json
# ✅ Copiato:
#   vslnet_25_16422_preds.json → vslbase_25_16422_preds.json
# ✅ Copiato:
#   vslnet_25_16744_preds.json → vslbase_25_16744_preds.json
# ✅ Copiato:
#   vslnet_25_16770_preds.json → vslbase_25_16770_preds.json
# ✅ Copiato:
#   vslnet_26_17066_preds.json → vslbase_26_17066_preds.json
# ✅ Copiato:
#   vslnet_26_17388_preds.json → vslbase_26_17388_preds.json
# ✅ Copiato:
#   vslnet_26_17415_preds.json → vslbase_26_17415_preds.json
# ✅ Copiato:
#   vslnet_27_17710_preds.json → vslbase_27_17710_preds.json
# ✅ Copiato:
#   vslnet_27_18032_preds.json → vslbase_27_18032_preds.json
# ✅ Copiato:
#   vslnet_27_18060_preds.json → vslbase_27_18060_preds.json
# ✅ Copiato:
#   vslnet_28_18354_preds.json → vslbase_28_18354_preds.json
# ✅ Copiato:
#   vslnet_28_18676_preds.json → vslbase_28_18676_preds.json
# ✅ Copiato:
#   vslnet_28_18705_preds.json → vslbase_28_18705_preds.json
# ✅ Copiato:
#   vslnet_29_18998_preds.json → vslbase_29_18998_preds.json
# ✅ Copiato:
#   vslnet_33_21574_preds.json → vslbase_33_21574_preds.json
# ✅ Copiato:
#   vslnet_29_19350_preds.json → vslbase_29_19350_preds.json
# ✅ Copiato:
#   vslnet_30_19642_preds.json → vslbase_30_19642_preds.json
# ✅ Copiato:
#   vslnet_33_21896_preds.json → vslbase_33_21896_preds.json
# ✅ Copiato:
#   vslnet_30_19995_preds.json → vslbase_30_19995_preds.json
# ✅ Copiato:
#   vslnet_31_20286_preds.json → vslbase_31_20286_preds.json
# ✅ Copiato:
#   vslnet_33_21930_preds.json → vslbase_33_21930_preds.json
# ✅ Copiato:
#   vslnet_31_20640_preds.json → vslbase_31_20640_preds.json
# ✅ Copiato:
#   vslnet_32_20930_preds.json → vslbase_32_20930_preds.json
# ✅ Copiato:
#   vslnet_32_21252_preds.json → vslbase_32_21252_preds.json
# ✅ Copiato:
#   vslnet_32_21285_preds.json → vslbase_32_21285_preds.json
# ✅ Copiato:
#   vslnet_34_22218_preds.json → vslbase_34_22218_preds.json
# ✅ Copiato:
#   vslnet_36_23828_preds.json → vslbase_36_23828_preds.json
# ✅ Copiato:
#   vslnet_37_24150_preds.json → vslbase_37_24150_preds.json
# ✅ Copiato:
#   vslnet_39_25760_preds.json → vslbase_39_25760_preds.json
# ✅ Copiato:
#   vslnet_34_22540_preds.json → vslbase_34_22540_preds.json
# ✅ Copiato:
#   vslnet_34_22575_preds.json → vslbase_34_22575_preds.json
# ✅ Copiato:
#   vslnet_35_22862_preds.json → vslbase_35_22862_preds.json
# ✅ Copiato:
#   vslnet_35_23184_preds.json → vslbase_35_23184_preds.json
# ✅ Copiato:
#   vslnet_35_23220_preds.json → vslbase_35_23220_preds.json
# ✅ Copiato:
#   vslnet_36_23506_preds.json → vslbase_36_23506_preds.json
# ✅ Copiato:
#   vslnet_40_26445_preds.json → vslbase_40_26445_preds.json
# ✅ Copiato:
#   vslnet_36_23865_preds.json → vslbase_36_23865_preds.json
# ✅ Copiato:
#   vslnet_44_28980_preds.json → vslbase_44_28980_preds.json
# ✅ Copiato:
#   vslnet_37_24472_preds.json → vslbase_37_24472_preds.json
# ✅ Copiato:
#   vslnet_37_24510_preds.json → vslbase_37_24510_preds.json
# ✅ Copiato:
#   vslnet_38_24794_preds.json → vslbase_38_24794_preds.json
# ✅ Copiato:
#   vslnet_38_25116_preds.json → vslbase_38_25116_preds.json
# ✅ Copiato:
#   vslnet_38_25155_preds.json → vslbase_38_25155_preds.json
# ✅ Copiato:
#   vslnet_39_25438_preds.json → vslbase_39_25438_preds.json
# ✅ Copiato:
#   vslnet_44_29025_preds.json → vslbase_44_29025_preds.json
# ✅ Copiato:
#   vslnet_39_25800_preds.json → vslbase_39_25800_preds.json
# ✅ Copiato:
#   vslnet_40_26082_preds.json → vslbase_40_26082_preds.json
# ✅ Copiato:
#   vslnet_40_26404_preds.json → vslbase_40_26404_preds.json
# ✅ Copiato:
#   vslnet_46_29946_preds.json → vslbase_46_29946_preds.json
# ✅ Copiato:
#   vslnet_41_26726_preds.json → vslbase_41_26726_preds.json
# ✅ Copiato:
#   vslnet_41_27048_preds.json → vslbase_41_27048_preds.json
# ✅ Copiato:
#   vslnet_41_27090_preds.json → vslbase_41_27090_preds.json
# ✅ Copiato:
#   vslnet_42_27370_preds.json → vslbase_42_27370_preds.json
# ✅ Copiato:
#   vslnet_42_27692_preds.json → vslbase_42_27692_preds.json
# ✅ Copiato:
#   vslnet_42_27735_preds.json → vslbase_42_27735_preds.json
# ✅ Copiato:
#   vslnet_43_28014_preds.json → vslbase_43_28014_preds.json
# ✅ Copiato:
#   vslnet_43_28336_preds.json → vslbase_43_28336_preds.json
# ✅ Copiato:
#   vslnet_43_28380_preds.json → vslbase_43_28380_preds.json
# ✅ Copiato:
#   vslnet_44_28658_preds.json → vslbase_44_28658_preds.json
# ✅ Copiato:
#   vslnet_48_31556_preds.json → vslbase_48_31556_preds.json
# ✅ Copiato:
#   vslnet_49_32200_preds.json → vslbase_49_32200_preds.json
# ✅ Copiato:
#   vslnet_45_29302_preds.json → vslbase_45_29302_preds.json
# ✅ Copiato:
#   vslnet_45_29624_preds.json → vslbase_45_29624_preds.json
# ✅ Copiato:
#   vslnet_45_29670_preds.json → vslbase_45_29670_preds.json
# ✅ Copiato:
#   vslnet_50_32522_preds.json → vslbase_50_32522_preds.json
# ✅ Copiato:
#   vslnet_46_30268_preds.json → vslbase_46_30268_preds.json
# ✅ Copiato:
#   vslnet_46_30315_preds.json → vslbase_46_30315_preds.json
# ✅ Copiato:
#   vslnet_47_30590_preds.json → vslbase_47_30590_preds.json
# ✅ Copiato:
#   vslnet_47_30912_preds.json → vslbase_47_30912_preds.json
# ✅ Copiato:
#   vslnet_47_30960_preds.json → vslbase_47_30960_preds.json
# ✅ Copiato:
#   vslnet_48_31234_preds.json → vslbase_48_31234_preds.json
# ✅ Copiato:
#   vslnet_51_33166_preds.json → vslbase_51_33166_preds.json
# ✅ Copiato:
#   vslnet_48_31605_preds.json → vslbase_48_31605_preds.json
# ✅ Copiato:
#   vslnet_49_31878_preds.json → vslbase_49_31878_preds.json
# ✅ Copiato:
#   vslnet_53_34830_preds.json → vslbase_53_34830_preds.json
# ✅ Copiato:
#   vslnet_49_32250_preds.json → vslbase_49_32250_preds.json
# ✅ Copiato:
#   vslnet_57_37030_preds.json → vslbase_57_37030_preds.json
# ✅ Copiato:
#   vslnet_50_32844_preds.json → vslbase_50_32844_preds.json
# ✅ Copiato:
#   vslnet_50_32895_preds.json → vslbase_50_32895_preds.json
# ✅ Copiato:
#   vslnet_57_37410_preds.json → vslbase_57_37410_preds.json
# ✅ Copiato:
#   vslnet_51_33488_preds.json → vslbase_51_33488_preds.json
# ✅ Copiato:
#   vslnet_51_33540_preds.json → vslbase_51_33540_preds.json
# ✅ Copiato:
#   vslnet_52_33810_preds.json → vslbase_52_33810_preds.json
# ✅ Copiato:
#   vslnet_52_34132_preds.json → vslbase_52_34132_preds.json
# ✅ Copiato:
#   vslnet_52_34185_preds.json → vslbase_52_34185_preds.json
# ✅ Copiato:
#   vslnet_53_34454_preds.json → vslbase_53_34454_preds.json
# ✅ Copiato:
#   vslnet_53_34776_preds.json → vslbase_53_34776_preds.json
# ✅ Copiato:
#   vslnet_59_38318_preds.json → vslbase_59_38318_preds.json
# ✅ Copiato:
#   vslnet_54_35098_preds.json → vslbase_54_35098_preds.json
# ✅ Copiato:
#   vslnet_54_35420_preds.json → vslbase_54_35420_preds.json
# ✅ Copiato:
#   vslnet_54_35475_preds.json → vslbase_54_35475_preds.json
# ✅ Copiato:
#   vslnet_55_35742_preds.json → vslbase_55_35742_preds.json
# ✅ Copiato:
#   vslnet_55_36064_preds.json → vslbase_55_36064_preds.json
# ✅ Copiato:
#   vslnet_55_36120_preds.json → vslbase_55_36120_preds.json
# ✅ Copiato:
#   vslnet_56_36386_preds.json → vslbase_56_36386_preds.json
# ✅ Copiato:
#   vslnet_56_36708_preds.json → vslbase_56_36708_preds.json
# ✅ Copiato:
#   vslnet_56_36765_preds.json → vslbase_56_36765_preds.json
# ✅ Copiato:
#   vslnet_60_38962_preds.json → vslbase_60_38962_preds.json
# ✅ Copiato:
#   vslnet_57_37352_preds.json → vslbase_57_37352_preds.json
# ✅ Copiato:
#   vslnet_61_39990_preds.json → vslbase_61_39990_preds.json
# ✅ Copiato:
#   vslnet_58_37674_preds.json → vslbase_58_37674_preds.json
# ✅ Copiato:
#   vslnet_58_37996_preds.json → vslbase_58_37996_preds.json
# ✅ Copiato:
#   vslnet_58_38055_preds.json → vslbase_58_38055_preds.json
# ✅ Copiato:
#   vslnet_62_40572_preds.json → vslbase_62_40572_preds.json
# ✅ Copiato:
#   vslnet_59_38640_preds.json → vslbase_59_38640_preds.json
# ✅ Copiato:
#   vslnet_59_38700_preds.json → vslbase_59_38700_preds.json
# ✅ Copiato:
#   vslnet_63_40894_preds.json → vslbase_63_40894_preds.json
# ✅ Copiato:
#   vslnet_60_39284_preds.json → vslbase_60_39284_preds.json
# ✅ Copiato:
#   vslnet_60_39345_preds.json → vslbase_60_39345_preds.json
# ✅ Copiato:
#   vslnet_61_39606_preds.json → vslbase_61_39606_preds.json
# ✅ Copiato:
#   vslnet_61_39928_preds.json → vslbase_61_39928_preds.json
# ✅ Copiato:
#   vslnet_64_41925_preds.json → vslbase_64_41925_preds.json
# ✅ Copiato:
#   vslnet_62_40250_preds.json → vslbase_62_40250_preds.json
# ✅ Copiato:
#   vslnet_65_42570_preds.json → vslbase_65_42570_preds.json
# ✅ Copiato:
#   vslnet_62_40635_preds.json → vslbase_62_40635_preds.json
# ✅ Copiato:
#   vslnet_68_44436_preds.json → vslbase_68_44436_preds.json
# ✅ Copiato:
#   vslnet_63_41216_preds.json → vslbase_63_41216_preds.json
# ✅ Copiato:
#   vslnet_63_41280_preds.json → vslbase_63_41280_preds.json
# ✅ Copiato:
#   vslnet_64_41538_preds.json → vslbase_64_41538_preds.json
# ✅ Copiato:
#   vslnet_64_41860_preds.json → vslbase_64_41860_preds.json
# ✅ Copiato:
#   vslnet_74_48375_preds.json → vslbase_74_48375_preds.json
# ✅ Copiato:
#   vslnet_65_42182_preds.json → vslbase_65_42182_preds.json
# ✅ Copiato:
#   vslnet_65_42504_preds.json → vslbase_65_42504_preds.json
# ✅ Copiato:
#   vslnet_79_51198_preds.json → vslbase_79_51198_preds.json
# ✅ Copiato:
#   vslnet_66_42826_preds.json → vslbase_66_42826_preds.json
# ✅ Copiato:
#   vslnet_66_43148_preds.json → vslbase_66_43148_preds.json
# ✅ Copiato:
#   vslnet_66_43215_preds.json → vslbase_66_43215_preds.json
# ✅ Copiato:
#   vslnet_67_43470_preds.json → vslbase_67_43470_preds.json
# ✅ Copiato:
#   vslnet_67_43792_preds.json → vslbase_67_43792_preds.json
# ✅ Copiato:
#   vslnet_67_43860_preds.json → vslbase_67_43860_preds.json
# ✅ Copiato:
#   vslnet_68_44114_preds.json → vslbase_68_44114_preds.json
# ✅ Copiato:
#   vslnet_110_71595_preds.json → vslbase_110_71595_preds.json
# ✅ Copiato:
#   vslnet_68_44505_preds.json → vslbase_68_44505_preds.json
# ✅ Copiato:
#   vslnet_69_44758_preds.json → vslbase_69_44758_preds.json
# ✅ Copiato:
#   vslnet_69_45080_preds.json → vslbase_69_45080_preds.json
# ✅ Copiato:
#   vslnet_69_45150_preds.json → vslbase_69_45150_preds.json
# ✅ Copiato:
#   vslnet_70_45402_preds.json → vslbase_70_45402_preds.json
# ✅ Copiato:
#   vslnet_70_45724_preds.json → vslbase_70_45724_preds.json
# ✅ Copiato:
#   vslnet_70_45795_preds.json → vslbase_70_45795_preds.json
# ✅ Copiato:
#   vslnet_71_46046_preds.json → vslbase_71_46046_preds.json
# ✅ Copiato:
#   vslnet_71_46368_preds.json → vslbase_71_46368_preds.json
# ✅ Copiato:
#   vslnet_71_46440_preds.json → vslbase_71_46440_preds.json
# ✅ Copiato:
#   vslnet_72_46690_preds.json → vslbase_72_46690_preds.json
# ✅ Copiato:
#   vslnet_72_47012_preds.json → vslbase_72_47012_preds.json
# ✅ Copiato:
#   vslnet_72_47085_preds.json → vslbase_72_47085_preds.json
# ✅ Copiato:
#   vslnet_73_47334_preds.json → vslbase_73_47334_preds.json
# ✅ Copiato:
#   vslnet_73_47656_preds.json → vslbase_73_47656_preds.json
# ✅ Copiato:
#   vslnet_73_47730_preds.json → vslbase_73_47730_preds.json
# ✅ Copiato:
#   vslnet_74_47978_preds.json → vslbase_74_47978_preds.json
# ✅ Copiato:
#   vslnet_74_48300_preds.json → vslbase_74_48300_preds.json
# ✅ Copiato:
#   vslnet_118_76755_preds.json → vslbase_118_76755_preds.json
# ✅ Copiato:
#   vslnet_75_48622_preds.json → vslbase_75_48622_preds.json
# ✅ Copiato:
#   vslnet_75_48944_preds.json → vslbase_75_48944_preds.json
# ✅ Copiato:
#   vslnet_75_49020_preds.json → vslbase_75_49020_preds.json
# ✅ Copiato:
#   vslnet_76_49266_preds.json → vslbase_76_49266_preds.json
# ✅ Copiato:
#   vslnet_76_49588_preds.json → vslbase_76_49588_preds.json
# ✅ Copiato:
#   vslnet_76_49665_preds.json → vslbase_76_49665_preds.json
# ✅ Copiato:
#   vslnet_77_49910_preds.json → vslbase_77_49910_preds.json
# ✅ Copiato:
#   vslnet_77_50232_preds.json → vslbase_77_50232_preds.json
# ✅ Copiato:
#   vslnet_77_50310_preds.json → vslbase_77_50310_preds.json
# ✅ Copiato:
#   vslnet_78_50554_preds.json → vslbase_78_50554_preds.json
# ✅ Copiato:
#   vslnet_78_50876_preds.json → vslbase_78_50876_preds.json
# ✅ Copiato:
#   vslnet_78_50955_preds.json → vslbase_78_50955_preds.json
# ✅ Copiato:
#   vslnet_119_77400_preds.json → vslbase_119_77400_preds.json
# ✅ Copiato:
#   vslnet_79_51520_preds.json → vslbase_79_51520_preds.json
# ✅ Copiato:
#   vslnet_79_51600_preds.json → vslbase_79_51600_preds.json
# ✅ Copiato:
#   vslnet_80_51842_preds.json → vslbase_80_51842_preds.json
# ✅ Copiato:
#   vslnet_80_52164_preds.json → vslbase_80_52164_preds.json
# ✅ Copiato:
#   vslnet_80_52245_preds.json → vslbase_80_52245_preds.json
# ✅ Copiato:
#   vslnet_81_52486_preds.json → vslbase_81_52486_preds.json
# ✅ Copiato:
#   vslnet_81_52808_preds.json → vslbase_81_52808_preds.json
# ✅ Copiato:
#   vslnet_81_52890_preds.json → vslbase_81_52890_preds.json
# ✅ Copiato:
#   vslnet_82_53130_preds.json → vslbase_82_53130_preds.json
# ✅ Copiato:
#   vslnet_82_53452_preds.json → vslbase_82_53452_preds.json
# ✅ Copiato:
#   vslnet_82_53535_preds.json → vslbase_82_53535_preds.json
# ✅ Copiato:
#   vslnet_83_53774_preds.json → vslbase_83_53774_preds.json
# ✅ Copiato:
#   vslnet_83_54096_preds.json → vslbase_83_54096_preds.json
# ✅ Copiato:
#   vslnet_83_54180_preds.json → vslbase_83_54180_preds.json
# ✅ Copiato:
#   vslnet_84_54418_preds.json → vslbase_84_54418_preds.json
# ✅ Copiato:
#   vslnet_84_54740_preds.json → vslbase_84_54740_preds.json
# ✅ Copiato:
#   vslnet_84_54825_preds.json → vslbase_84_54825_preds.json
# ✅ Copiato:
#   vslnet_85_55062_preds.json → vslbase_85_55062_preds.json
# ✅ Copiato:
#   vslnet_85_55384_preds.json → vslbase_85_55384_preds.json
# ✅ Copiato:
#   vslnet_85_55470_preds.json → vslbase_85_55470_preds.json
# ✅ Copiato:
#   vslnet_86_55706_preds.json → vslbase_86_55706_preds.json
# ✅ Copiato:
#   vslnet_86_56028_preds.json → vslbase_86_56028_preds.json
# ✅ Copiato:
#   vslnet_86_56115_preds.json → vslbase_86_56115_preds.json
# ✅ Copiato:
#   vslnet_87_56350_preds.json → vslbase_87_56350_preds.json
# ✅ Copiato:
#   vslnet_87_56672_preds.json → vslbase_87_56672_preds.json
# ✅ Copiato:
#   vslnet_87_56760_preds.json → vslbase_87_56760_preds.json
# ✅ Copiato:
#   vslnet_88_56994_preds.json → vslbase_88_56994_preds.json
# ✅ Copiato:
#   vslnet_88_57316_preds.json → vslbase_88_57316_preds.json
# ✅ Copiato:
#   vslnet_88_57405_preds.json → vslbase_88_57405_preds.json
# ✅ Copiato:
#   vslnet_89_57638_preds.json → vslbase_89_57638_preds.json
# ✅ Copiato:
#   vslnet_89_57960_preds.json → vslbase_89_57960_preds.json
# ✅ Copiato:
#   vslnet_89_58050_preds.json → vslbase_89_58050_preds.json
# ✅ Copiato:
#   vslnet_90_58282_preds.json → vslbase_90_58282_preds.json
# ✅ Copiato:
#   vslnet_90_58604_preds.json → vslbase_90_58604_preds.json
# ✅ Copiato:
#   vslnet_90_58695_preds.json → vslbase_90_58695_preds.json
# ✅ Copiato:
#   vslnet_91_58926_preds.json → vslbase_91_58926_preds.json
# ✅ Copiato:
#   vslnet_91_59248_preds.json → vslbase_91_59248_preds.json
# ✅ Copiato:
#   vslnet_91_59340_preds.json → vslbase_91_59340_preds.json
# ✅ Copiato:
#   vslnet_92_59570_preds.json → vslbase_92_59570_preds.json
# ✅ Copiato:
#   vslnet_92_59892_preds.json → vslbase_92_59892_preds.json
# ✅ Copiato:
#   vslnet_92_59985_preds.json → vslbase_92_59985_preds.json
# ✅ Copiato:
#   vslnet_93_60214_preds.json → vslbase_93_60214_preds.json
# ✅ Copiato:
#   vslnet_93_60536_preds.json → vslbase_93_60536_preds.json
# ✅ Copiato:
#   vslnet_93_60630_preds.json → vslbase_93_60630_preds.json
# ✅ Copiato:
#   vslnet_94_60858_preds.json → vslbase_94_60858_preds.json
# ✅ Copiato:
#   vslnet_94_61180_preds.json → vslbase_94_61180_preds.json
# ✅ Copiato:
#   vslnet_94_61275_preds.json → vslbase_94_61275_preds.json
# ✅ Copiato:
#   vslnet_95_61502_preds.json → vslbase_95_61502_preds.json
# ✅ Copiato:
#   vslnet_95_61824_preds.json → vslbase_95_61824_preds.json
# ✅ Copiato:
#   vslnet_95_61920_preds.json → vslbase_95_61920_preds.json
# ✅ Copiato:
#   vslnet_96_62146_preds.json → vslbase_96_62146_preds.json
# ✅ Copiato:
#   vslnet_96_62468_preds.json → vslbase_96_62468_preds.json
# ✅ Copiato:
#   vslnet_96_62565_preds.json → vslbase_96_62565_preds.json
# ✅ Copiato:
#   vslnet_97_62790_preds.json → vslbase_97_62790_preds.json
# ✅ Copiato:
#   vslnet_97_63112_preds.json → vslbase_97_63112_preds.json
# ✅ Copiato:
#   vslnet_97_63210_preds.json → vslbase_97_63210_preds.json
# ✅ Copiato:
#   vslnet_98_63434_preds.json → vslbase_98_63434_preds.json
# ✅ Copiato:
#   vslnet_98_63756_preds.json → vslbase_98_63756_preds.json
# ✅ Copiato:
#   vslnet_98_63855_preds.json → vslbase_98_63855_preds.json
# ✅ Copiato:
#   vslnet_99_64078_preds.json → vslbase_99_64078_preds.json
# ✅ Copiato:
#   vslnet_99_64400_preds.json → vslbase_99_64400_preds.json
# ✅ Copiato:
#   vslnet_99_64500_preds.json → vslbase_99_64500_preds.json
# ✅ Copiato:
#   vslnet_100_64722_preds.json → vslbase_100_64722_preds.json
# ✅ Copiato:
#   vslnet_100_65044_preds.json → vslbase_100_65044_preds.json
# ✅ Copiato:
#   vslnet_100_65145_preds.json → vslbase_100_65145_preds.json
# ✅ Copiato:
#   vslnet_101_65366_preds.json → vslbase_101_65366_preds.json
# ✅ Copiato:
#   vslnet_101_65688_preds.json → vslbase_101_65688_preds.json
# ✅ Copiato:
#   vslnet_101_65790_preds.json → vslbase_101_65790_preds.json
# ✅ Copiato:
#   vslnet_102_66010_preds.json → vslbase_102_66010_preds.json
# ✅ Copiato:
#   vslnet_102_66332_preds.json → vslbase_102_66332_preds.json
# ✅ Copiato:
#   vslnet_102_66435_preds.json → vslbase_102_66435_preds.json
# ✅ Copiato:
#   vslnet_103_66654_preds.json → vslbase_103_66654_preds.json
# ✅ Copiato:
#   vslnet_103_66976_preds.json → vslbase_103_66976_preds.json
# ✅ Copiato:
#   vslnet_103_67080_preds.json → vslbase_103_67080_preds.json
# ✅ Copiato:
#   vslnet_104_67298_preds.json → vslbase_104_67298_preds.json
# ✅ Copiato:
#   vslnet_104_67620_preds.json → vslbase_104_67620_preds.json
# ✅ Copiato:
#   vslnet_104_67725_preds.json → vslbase_104_67725_preds.json
# ✅ Copiato:
#   vslnet_105_67942_preds.json → vslbase_105_67942_preds.json
# ✅ Copiato:
#   vslnet_105_68264_preds.json → vslbase_105_68264_preds.json
# ✅ Copiato:
#   vslnet_105_68370_preds.json → vslbase_105_68370_preds.json
# ✅ Copiato:
#   vslnet_106_68586_preds.json → vslbase_106_68586_preds.json
# ✅ Copiato:
#   vslnet_106_68908_preds.json → vslbase_106_68908_preds.json
# ✅ Copiato:
#   vslnet_106_69015_preds.json → vslbase_106_69015_preds.json
# ✅ Copiato:
#   vslnet_107_69230_preds.json → vslbase_107_69230_preds.json
# ✅ Copiato:
#   vslnet_107_69552_preds.json → vslbase_107_69552_preds.json
# ✅ Copiato:
#   vslnet_107_69660_preds.json → vslbase_107_69660_preds.json
# ✅ Copiato:
#   vslnet_108_69874_preds.json → vslbase_108_69874_preds.json
# ✅ Copiato:
#   vslnet_108_70196_preds.json → vslbase_108_70196_preds.json
# ✅ Copiato:
#   vslnet_108_70305_preds.json → vslbase_108_70305_preds.json
# ✅ Copiato:
#   vslnet_109_70518_preds.json → vslbase_109_70518_preds.json
# ✅ Copiato:
#   vslnet_109_70840_preds.json → vslbase_109_70840_preds.json
# ✅ Copiato:
#   vslnet_109_70950_preds.json → vslbase_109_70950_preds.json
# ✅ Copiato:
#   vslnet_110_71162_preds.json → vslbase_110_71162_preds.json
# ✅ Copiato:
#   vslnet_110_71484_preds.json → vslbase_110_71484_preds.json
# ✅ Copiato:
#   vslnet_124_80625_preds.json → vslbase_124_80625_preds.json
# ✅ Copiato:
#   vslnet_111_71806_preds.json → vslbase_111_71806_preds.json
# ✅ Copiato:
#   vslnet_111_72128_preds.json → vslbase_111_72128_preds.json
# ✅ Copiato:
#   vslnet_111_72240_preds.json → vslbase_111_72240_preds.json
# ✅ Copiato:
#   vslnet_112_72450_preds.json → vslbase_112_72450_preds.json
# ✅ Copiato:
#   vslnet_112_72772_preds.json → vslbase_112_72772_preds.json
# ✅ Copiato:
#   vslnet_112_72885_preds.json → vslbase_112_72885_preds.json
# ✅ Copiato:
#   vslnet_113_73094_preds.json → vslbase_113_73094_preds.json
# ✅ Copiato:
#   vslnet_113_73416_preds.json → vslbase_113_73416_preds.json
# ✅ Copiato:
#   vslnet_113_73530_preds.json → vslbase_113_73530_preds.json
# ✅ Copiato:
#   vslnet_114_73738_preds.json → vslbase_114_73738_preds.json
# ✅ Copiato:
#   vslnet_114_74060_preds.json → vslbase_114_74060_preds.json
# ✅ Copiato:
#   vslnet_114_74175_preds.json → vslbase_114_74175_preds.json
# ✅ Copiato:
#   vslnet_115_74382_preds.json → vslbase_115_74382_preds.json
# ✅ Copiato:
#   vslnet_115_74704_preds.json → vslbase_115_74704_preds.json
# ✅ Copiato:
#   vslnet_115_74820_preds.json → vslbase_115_74820_preds.json
# ✅ Copiato:
#   vslnet_116_75026_preds.json → vslbase_116_75026_preds.json
# ✅ Copiato:
#   vslnet_116_75348_preds.json → vslbase_116_75348_preds.json
# ✅ Copiato:
#   vslnet_116_75465_preds.json → vslbase_116_75465_preds.json
# ✅ Copiato:
#   vslnet_117_75670_preds.json → vslbase_117_75670_preds.json
# ✅ Copiato:
#   vslnet_117_75992_preds.json → vslbase_117_75992_preds.json
# ✅ Copiato:
#   vslnet_117_76110_preds.json → vslbase_117_76110_preds.json
# ✅ Copiato:
#   vslnet_118_76314_preds.json → vslbase_118_76314_preds.json
# ✅ Copiato:
#   vslnet_118_76636_preds.json → vslbase_118_76636_preds.json
# ✅ Copiato:
#   vslnet_125_80822_preds.json → vslbase_125_80822_preds.json
# ✅ Copiato:
#   vslnet_119_76958_preds.json → vslbase_119_76958_preds.json
# ✅ Copiato:
#   vslnet_119_77280_preds.json → vslbase_119_77280_preds.json
# ✅ Copiato:
#   vslnet_129_83720_preds.json → vslbase_129_83720_preds.json
# ✅ Copiato:
#   vslnet_120_77602_preds.json → vslbase_120_77602_preds.json
# ✅ Copiato:
#   vslnet_120_77924_preds.json → vslbase_120_77924_preds.json
# ✅ Copiato:
#   vslnet_120_78045_preds.json → vslbase_120_78045_preds.json
# ✅ Copiato:
#   vslnet_121_78246_preds.json → vslbase_121_78246_preds.json
# ✅ Copiato:
#   vslnet_121_78568_preds.json → vslbase_121_78568_preds.json
# ✅ Copiato:
#   vslnet_121_78690_preds.json → vslbase_121_78690_preds.json
# ✅ Copiato:
#   vslnet_122_78890_preds.json → vslbase_122_78890_preds.json
# ✅ Copiato:
#   vslnet_122_79212_preds.json → vslbase_122_79212_preds.json
# ✅ Copiato:
#   vslnet_122_79335_preds.json → vslbase_122_79335_preds.json
# ✅ Copiato:
#   vslnet_123_79534_preds.json → vslbase_123_79534_preds.json
# ✅ Copiato:
#   vslnet_123_79856_preds.json → vslbase_123_79856_preds.json
# ✅ Copiato:
#   vslnet_123_79980_preds.json → vslbase_123_79980_preds.json
# ✅ Copiato:
#   vslnet_124_80178_preds.json → vslbase_124_80178_preds.json
# ✅ Copiato:
#   vslnet_124_80500_preds.json → vslbase_124_80500_preds.json
# ✅ Copiato:
#   vslnet_125_81144_preds.json → vslbase_125_81144_preds.json
# ✅ Copiato:
#   vslnet_125_81270_preds.json → vslbase_125_81270_preds.json
# ✅ Copiato:
#   vslnet_126_81466_preds.json → vslbase_126_81466_preds.json
# ✅ Copiato:
#   vslnet_126_81788_preds.json → vslbase_126_81788_preds.json
# ✅ Copiato:
#   vslnet_126_81915_preds.json → vslbase_126_81915_preds.json
# ✅ Copiato:
#   vslnet_127_82110_preds.json → vslbase_127_82110_preds.json
# ✅ Copiato:
#   vslnet_127_82432_preds.json → vslbase_127_82432_preds.json
# ✅ Copiato:
#   vslnet_127_82560_preds.json → vslbase_127_82560_preds.json
# ✅ Copiato:
#   vslnet_128_82754_preds.json → vslbase_128_82754_preds.json
# ✅ Copiato:
#   vslnet_128_83076_preds.json → vslbase_128_83076_preds.json
# ✅ Copiato:
#   vslnet_128_83205_preds.json → vslbase_128_83205_preds.json
# ✅ Copiato:
#   vslnet_129_83398_preds.json → vslbase_129_83398_preds.json
# ✅ Copiato:
#   vslnet_129_83850_preds.json → vslbase_129_83850_preds.json
# ✅ Copiato:
#   vslnet_130_84042_preds.json → vslbase_130_84042_preds.json
# ✅ Copiato:
#   vslnet_130_84364_preds.json → vslbase_130_84364_preds.json
# ✅ Copiato:
#   vslnet_130_84495_preds.json → vslbase_130_84495_preds.json
# ✅ Copiato:
#   vslnet_131_84686_preds.json → vslbase_131_84686_preds.json
# ✅ Copiato:
#   vslnet_131_85008_preds.json → vslbase_131_85008_preds.json
# ✅ Copiato:
#   vslnet_131_85140_preds.json → vslbase_131_85140_preds.json
# ✅ Copiato:
#   vslnet_132_85330_preds.json → vslbase_132_85330_preds.json
# ✅ Copiato:
#   vslnet_132_85652_preds.json → vslbase_132_85652_preds.json
# ✅ Copiato:
#   vslnet_132_85785_preds.json → vslbase_132_85785_preds.json
# ✅ Copiato:
#   vslnet_133_85974_preds.json → vslbase_133_85974_preds.json
# ✅ Copiato:
#   vslnet_133_86296_preds.json → vslbase_133_86296_preds.json
# ✅ Copiato:
#   vslnet_133_86430_preds.json → vslbase_133_86430_preds.json
# ✅ Copiato:
#   vslnet_134_86618_preds.json → vslbase_134_86618_preds.json
# ✅ Copiato:
#   vslnet_134_86940_preds.json → vslbase_134_86940_preds.json
# ✅ Copiato:
#   vslnet_134_87075_preds.json → vslbase_134_87075_preds.json
# ✅ Copiato:
#   vslnet_135_87262_preds.json → vslbase_135_87262_preds.json
# ✅ Copiato:
#   vslnet_135_87584_preds.json → vslbase_135_87584_preds.json
# ✅ Copiato:
#   vslnet_135_87720_preds.json → vslbase_135_87720_preds.json
# ✅ Copiato:
#   vslnet_136_87906_preds.json → vslbase_136_87906_preds.json
# ✅ Copiato:
#   vslnet_136_88228_preds.json → vslbase_136_88228_preds.json
# ✅ Copiato:
#   vslnet_136_88365_preds.json → vslbase_136_88365_preds.json
# ✅ Copiato:
#   vslnet_137_88550_preds.json → vslbase_137_88550_preds.json
# ✅ Copiato:
#   vslnet_137_88872_preds.json → vslbase_137_88872_preds.json
# ✅ Copiato:
#   vslnet_137_89010_preds.json → vslbase_137_89010_preds.json
# ✅ Copiato:
#   vslnet_138_89194_preds.json → vslbase_138_89194_preds.json
# ✅ Copiato:
#   vslnet_138_89516_preds.json → vslbase_138_89516_preds.json
# ✅ Copiato:
#   vslnet_138_89655_preds.json → vslbase_138_89655_preds.json
# ✅ Copiato:
#   vslnet_139_89838_preds.json → vslbase_139_89838_preds.json
# ✅ Copiato:
#   vslnet_139_90160_preds.json → vslbase_139_90160_preds.json
# ✅ Copiato:
#   vslnet_139_90300_preds.json → vslbase_139_90300_preds.json
# ✅ Copiato:
#   vslnet_140_90482_preds.json → vslbase_140_90482_preds.json
# ✅ Copiato:
#   vslnet_140_90804_preds.json → vslbase_140_90804_preds.json
# ✅ Copiato:
#   vslnet_140_90945_preds.json → vslbase_140_90945_preds.json
# ✅ Copiato:
#   vslnet_141_91126_preds.json → vslbase_141_91126_preds.json
# ✅ Copiato:
#   vslnet_141_91448_preds.json → vslbase_141_91448_preds.json
# ✅ Copiato:
#   vslnet_141_91590_preds.json → vslbase_141_91590_preds.json
# ✅ Copiato:
#   vslnet_142_91770_preds.json → vslbase_142_91770_preds.json
# ✅ Copiato:
#   vslnet_142_92092_preds.json → vslbase_142_92092_preds.json
# ✅ Copiato:
#   vslnet_142_92235_preds.json → vslbase_142_92235_preds.json
# ✅ Copiato:
#   vslnet_143_92414_preds.json → vslbase_143_92414_preds.json
# ✅ Copiato:
#   vslnet_143_92736_preds.json → vslbase_143_92736_preds.json
# ✅ Copiato:
#   vslnet_143_92880_preds.json → vslbase_143_92880_preds.json
# ✅ Copiato:
#   vslnet_144_93058_preds.json → vslbase_144_93058_preds.json
# ✅ Copiato:
#   vslnet_144_93380_preds.json → vslbase_144_93380_preds.json
# ✅ Copiato:
#   vslnet_144_93525_preds.json → vslbase_144_93525_preds.json
# ✅ Copiato:
#   vslnet_145_93702_preds.json → vslbase_145_93702_preds.json
# ✅ Copiato:
#   vslnet_145_94024_preds.json → vslbase_145_94024_preds.json
# ✅ Copiato:
#   vslnet_145_94170_preds.json → vslbase_145_94170_preds.json
# ✅ Copiato:
#   vslnet_146_94346_preds.json → vslbase_146_94346_preds.json
# ✅ Copiato:
#   vslnet_146_94668_preds.json → vslbase_146_94668_preds.json
# ✅ Copiato:
#   vslnet_146_94815_preds.json → vslbase_146_94815_preds.json
# ✅ Copiato:
#   vslnet_147_94990_preds.json → vslbase_147_94990_preds.json
# ✅ Copiato:
#   vslnet_147_95312_preds.json → vslbase_147_95312_preds.json
# ✅ Copiato:
#   vslnet_147_95460_preds.json → vslbase_147_95460_preds.json
# ✅ Copiato:
#   vslnet_148_95634_preds.json → vslbase_148_95634_preds.json
# ✅ Copiato:
#   vslnet_148_95956_preds.json → vslbase_148_95956_preds.json
# ✅ Copiato:
#   vslnet_148_96105_preds.json → vslbase_148_96105_preds.json
# ✅ Copiato:
#   vslnet_149_96278_preds.json → vslbase_149_96278_preds.json
# ✅ Copiato:
#   vslnet_149_96600_preds.json → vslbase_149_96600_preds.json
# ✅ Copiato:
#   vslnet_149_96750_preds.json → vslbase_149_96750_preds.json
# ✅ Copiato:
#   vslnet_150_96922_preds.json → vslbase_150_96922_preds.json
# ✅ Copiato:
#   vslnet_150_97244_preds.json → vslbase_150_97244_preds.json
# ✅ Copiato:
#   vslnet_150_97395_preds.json → vslbase_150_97395_preds.json
# ✅ Copiato:
#   vslnet_151_97566_preds.json → vslbase_151_97566_preds.json
# ✅ Copiato:
#   vslnet_151_97888_preds.json → vslbase_151_97888_preds.json
# ✅ Copiato:
#   vslnet_151_98040_preds.json → vslbase_151_98040_preds.json
# ✅ Copiato:
#   vslnet_152_98210_preds.json → vslbase_152_98210_preds.json
# ✅ Copiato:
#   vslnet_152_98532_preds.json → vslbase_152_98532_preds.json
# ✅ Copiato:
#   vslnet_152_98685_preds.json → vslbase_152_98685_preds.json
# ✅ Copiato:
#   vslnet_153_98854_preds.json → vslbase_153_98854_preds.json
# ✅ Copiato:
#   vslnet_153_99176_preds.json → vslbase_153_99176_preds.json
# ✅ Copiato:
#   vslnet_153_99330_preds.json → vslbase_153_99330_preds.json
# ✅ Copiato:
#   vslnet_154_99498_preds.json → vslbase_154_99498_preds.json
# ✅ Copiato:
#   vslnet_154_99820_preds.json → vslbase_154_99820_preds.json
# ✅ Copiato:
#   vslnet_154_99975_preds.json → vslbase_154_99975_preds.json
# ✅ Copiato:
#   vslnet_155_100142_preds.json → vslbase_155_100142_preds.json
# ✅ Copiato:
#   vslnet_155_100464_preds.json → vslbase_155_100464_preds.json
# ✅ Copiato:
#   vslnet_155_100620_preds.json → vslbase_155_100620_preds.json
# ✅ Copiato:
#   vslnet_156_100786_preds.json → vslbase_156_100786_preds.json
# ✅ Copiato:
#   vslnet_156_101108_preds.json → vslbase_156_101108_preds.json
# ✅ Copiato:
#   vslnet_156_101265_preds.json → vslbase_156_101265_preds.json
# ✅ Copiato:
#   vslnet_157_101430_preds.json → vslbase_157_101430_preds.json
# ✅ Copiato:
#   vslnet_157_101752_preds.json → vslbase_157_101752_preds.json
# ✅ Copiato:
#   vslnet_157_101910_preds.json → vslbase_157_101910_preds.json
# ✅ Copiato:
#   vslnet_158_102074_preds.json → vslbase_158_102074_preds.json
# ✅ Copiato:
#   vslnet_158_102396_preds.json → vslbase_158_102396_preds.json
# ✅ Copiato:
#   vslnet_158_102555_preds.json → vslbase_158_102555_preds.json
# ✅ Copiato:
#   vslnet_159_102718_preds.json → vslbase_159_102718_preds.json
# ✅ Copiato:
#   vslnet_159_103040_preds.json → vslbase_159_103040_preds.json
# ✅ Copiato:
#   vslnet_159_103200_preds.json → vslbase_159_103200_preds.json
# ✅ Copiato:
#   vslnet_160_103362_preds.json → vslbase_160_103362_preds.json
# ✅ Copiato:
#   vslnet_160_103684_preds.json → vslbase_160_103684_preds.json
# ✅ Copiato:
#   vslnet_160_103845_preds.json → vslbase_160_103845_preds.json
# ✅ Copiato:
#   vslnet_161_104006_preds.json → vslbase_161_104006_preds.json
# ✅ Copiato:
#   vslnet_161_104328_preds.json → vslbase_161_104328_preds.json
# ✅ Copiato:
#   vslnet_161_104490_preds.json → vslbase_161_104490_preds.json
# ✅ Copiato:
#   vslnet_162_104650_preds.json → vslbase_162_104650_preds.json
# ✅ Copiato:
#   vslnet_162_104972_preds.json → vslbase_162_104972_preds.json
# ✅ Copiato:
#   vslnet_162_105135_preds.json → vslbase_162_105135_preds.json
# ✅ Copiato:
#   vslnet_163_105294_preds.json → vslbase_163_105294_preds.json
# ✅ Copiato:
#   vslnet_163_105616_preds.json → vslbase_163_105616_preds.json
# ✅ Copiato:
#   vslnet_163_105780_preds.json → vslbase_163_105780_preds.json
# ✅ Copiato:
#   vslnet_164_105938_preds.json → vslbase_164_105938_preds.json
# ✅ Copiato:
#   vslnet_164_106260_preds.json → vslbase_164_106260_preds.json
# ✅ Copiato:
#   vslnet_164_106425_preds.json → vslbase_164_106425_preds.json
# ✅ Copiato:
#   vslnet_165_106582_preds.json → vslbase_165_106582_preds.json
# ✅ Copiato:
#   vslnet_165_106904_preds.json → vslbase_165_106904_preds.json
# ✅ Copiato:
#   vslnet_165_107070_preds.json → vslbase_165_107070_preds.json
# ✅ Copiato:
#   vslnet_166_107226_preds.json → vslbase_166_107226_preds.json
# ✅ Copiato:
#   vslnet_166_107548_preds.json → vslbase_166_107548_preds.json
# ✅ Copiato:
#   vslnet_166_107715_preds.json → vslbase_166_107715_preds.json
# ✅ Copiato:
#   vslnet_167_107870_preds.json → vslbase_167_107870_preds.json
# ✅ Copiato:
#   vslnet_167_108192_preds.json → vslbase_167_108192_preds.json
# ✅ Copiato:
#   vslnet_167_108360_preds.json → vslbase_167_108360_preds.json
# ✅ Copiato:
#   vslnet_168_108514_preds.json → vslbase_168_108514_preds.json
# ✅ Copiato:
#   vslnet_168_108836_preds.json → vslbase_168_108836_preds.json
# ✅ Copiato:
#   vslnet_168_109005_preds.json → vslbase_168_109005_preds.json
# ✅ Copiato:
#   vslnet_169_109158_preds.json → vslbase_169_109158_preds.json
# ✅ Copiato:
#   vslnet_169_109480_preds.json → vslbase_169_109480_preds.json
# ✅ Copiato:
#   vslnet_169_109650_preds.json → vslbase_169_109650_preds.json
# ✅ Copiato:
#   vslnet_170_109802_preds.json → vslbase_170_109802_preds.json
# ✅ Copiato:
#   vslnet_170_110124_preds.json → vslbase_170_110124_preds.json
# ✅ Copiato:
#   vslnet_170_110295_preds.json → vslbase_170_110295_preds.json
# ✅ Copiato:
#   vslnet_171_110446_preds.json → vslbase_171_110446_preds.json
# ✅ Copiato:
#   vslnet_171_110768_preds.json → vslbase_171_110768_preds.json
# ✅ Copiato:
#   vslnet_171_110940_preds.json → vslbase_171_110940_preds.json
# ✅ Copiato:
#   vslnet_172_111090_preds.json → vslbase_172_111090_preds.json
# ✅ Copiato:
#   vslnet_172_111412_preds.json → vslbase_172_111412_preds.json
# ✅ Copiato:
#   vslnet_172_111585_preds.json → vslbase_172_111585_preds.json
# ✅ Copiato:
#   vslnet_173_111734_preds.json → vslbase_173_111734_preds.json
# ✅ Copiato:
#   vslnet_173_112056_preds.json → vslbase_173_112056_preds.json
# ✅ Copiato:
#   vslnet_173_112230_preds.json → vslbase_173_112230_preds.json
# ✅ Copiato:
#   vslnet_174_112378_preds.json → vslbase_174_112378_preds.json
# ✅ Copiato:
#   vslnet_174_112700_preds.json → vslbase_174_112700_preds.json
# ✅ Copiato:
#   vslnet_174_112875_preds.json → vslbase_174_112875_preds.json
# ✅ Copiato:
#   vslnet_175_113022_preds.json → vslbase_175_113022_preds.json
# ✅ Copiato:
#   vslnet_175_113344_preds.json → vslbase_175_113344_preds.json
# ✅ Copiato:
#   vslnet_175_113520_preds.json → vslbase_175_113520_preds.json
# ✅ Copiato:
#   vslnet_176_113666_preds.json → vslbase_176_113666_preds.json
# ✅ Copiato:
#   vslnet_176_113988_preds.json → vslbase_176_113988_preds.json
# ✅ Copiato:
#   vslnet_176_114165_preds.json → vslbase_176_114165_preds.json
# ✅ Copiato:
#   vslnet_177_114310_preds.json → vslbase_177_114310_preds.json
# ✅ Copiato:
#   vslnet_177_114632_preds.json → vslbase_177_114632_preds.json
# ✅ Copiato:
#   vslnet_177_114810_preds.json → vslbase_177_114810_preds.json
# ✅ Copiato:
#   vslnet_178_114954_preds.json → vslbase_178_114954_preds.json
# ✅ Copiato:
#   vslnet_178_115276_preds.json → vslbase_178_115276_preds.json
# ✅ Copiato:
#   vslnet_178_115455_preds.json → vslbase_178_115455_preds.json
# ✅ Copiato:
#   vslnet_179_115598_preds.json → vslbase_179_115598_preds.json
# ✅ Copiato:
#   vslnet_179_115920_preds.json → vslbase_179_115920_preds.json
# ✅ Copiato:
#   vslnet_179_116100_preds.json → vslbase_179_116100_preds.json
# ✅ Copiato:
#   vslnet_180_116242_preds.json → vslbase_180_116242_preds.json
# ✅ Copiato:
#   vslnet_180_116564_preds.json → vslbase_180_116564_preds.json
# ✅ Copiato:
#   vslnet_180_116745_preds.json → vslbase_180_116745_preds.json
# ✅ Copiato:
#   vslnet_181_116886_preds.json → vslbase_181_116886_preds.json
# ✅ Copiato:
#   vslnet_181_117208_preds.json → vslbase_181_117208_preds.json
# ✅ Copiato:
#   vslnet_181_117390_preds.json → vslbase_181_117390_preds.json
# ✅ Copiato:
#   vslnet_182_117530_preds.json → vslbase_182_117530_preds.json
# ✅ Copiato:
#   vslnet_182_117852_preds.json → vslbase_182_117852_preds.json
# ✅ Copiato:
#   vslnet_182_118035_preds.json → vslbase_182_118035_preds.json
# ✅ Copiato:
#   vslnet_183_118174_preds.json → vslbase_183_118174_preds.json
# ✅ Copiato:
#   vslnet_183_118496_preds.json → vslbase_183_118496_preds.json
# ✅ Copiato:
#   vslnet_183_118680_preds.json → vslbase_183_118680_preds.json
# ✅ Copiato:
#   vslnet_184_119325_preds.json → vslbase_184_119325_preds.json
# ✅ Copiato:
#   vslnet_185_119462_preds.json → vslbase_185_119462_preds.json
# ✅ Copiato:
#   vslnet_185_119784_preds.json → vslbase_185_119784_preds.json
# ✅ Copiato:
#   vslnet_185_119970_preds.json → vslbase_185_119970_preds.json
# ✅ Copiato:
#   vslnet_186_120106_preds.json → vslbase_186_120106_preds.json
# ✅ Copiato:
#   vslnet_186_120428_preds.json → vslbase_186_120428_preds.json
# ✅ Copiato:
#   vslnet_186_120615_preds.json → vslbase_186_120615_preds.json
# ✅ Copiato:
#   vslnet_187_120750_preds.json → vslbase_187_120750_preds.json
# ✅ Copiato:
#   vslnet_187_121072_preds.json → vslbase_187_121072_preds.json
# ✅ Copiato:
#   vslnet_187_121260_preds.json → vslbase_187_121260_preds.json
# ✅ Copiato:
#   vslnet_188_121394_preds.json → vslbase_188_121394_preds.json
# ✅ Copiato:
#   vslnet_188_121716_preds.json → vslbase_188_121716_preds.json
# ✅ Copiato:
#   vslnet_188_121905_preds.json → vslbase_188_121905_preds.json
# ✅ Copiato:
#   vslnet_189_122038_preds.json → vslbase_189_122038_preds.json
# ✅ Copiato:
#   vslnet_189_122360_preds.json → vslbase_189_122360_preds.json
# ✅ Copiato:
#   vslnet_189_122550_preds.json → vslbase_189_122550_preds.json
# ✅ Copiato:
#   vslnet_190_122682_preds.json → vslbase_190_122682_preds.json
# ✅ Copiato:
#   vslnet_190_123004_preds.json → vslbase_190_123004_preds.json
# ✅ Copiato:
#   vslnet_190_123195_preds.json → vslbase_190_123195_preds.json
# ✅ Copiato:
#   vslnet_191_123326_preds.json → vslbase_191_123326_preds.json
# ✅ Copiato:
#   vslnet_191_123648_preds.json → vslbase_191_123648_preds.json
# ✅ Copiato:
#   vslnet_191_123840_preds.json → vslbase_191_123840_preds.json
# ✅ Copiato:
#   vslnet_192_123970_preds.json → vslbase_192_123970_preds.json
# ✅ Copiato:
#   vslnet_192_124292_preds.json → vslbase_192_124292_preds.json
# ✅ Copiato:
#   vslnet_192_124485_preds.json → vslbase_192_124485_preds.json
# ✅ Copiato:
#   vslnet_193_124614_preds.json → vslbase_193_124614_preds.json
# ✅ Copiato:
#   vslnet_193_124936_preds.json → vslbase_193_124936_preds.json
# ✅ Copiato:
#   vslnet_193_125130_preds.json → vslbase_193_125130_preds.json
# ✅ Copiato:
#   vslnet_194_125258_preds.json → vslbase_194_125258_preds.json
# ✅ Copiato:
#   vslnet_194_125580_preds.json → vslbase_194_125580_preds.json
# ✅ Copiato:
#   vslnet_194_125775_preds.json → vslbase_194_125775_preds.json
# ✅ Copiato:
#   vslnet_195_125902_preds.json → vslbase_195_125902_preds.json
# ✅ Copiato:
#   vslnet_195_126224_preds.json → vslbase_195_126224_preds.json
# ✅ Copiato:
#   vslnet_195_126420_preds.json → vslbase_195_126420_preds.json
# ✅ Copiato:
#   vslnet_196_126546_preds.json → vslbase_196_126546_preds.json
# ✅ Copiato:
#   vslnet_196_126868_preds.json → vslbase_196_126868_preds.json
# ✅ Copiato:
#   vslnet_196_127065_preds.json → vslbase_196_127065_preds.json
# ✅ Copiato:
#   vslnet_197_127190_preds.json → vslbase_197_127190_preds.json
# ✅ Copiato:
#   vslnet_197_127512_preds.json → vslbase_197_127512_preds.json
# ✅ Copiato:
#   vslnet_197_127710_preds.json → vslbase_197_127710_preds.json
# ✅ Copiato:
#   vslnet_198_127834_preds.json → vslbase_198_127834_preds.json
# ✅ Copiato:
#   vslnet_198_128156_preds.json → vslbase_198_128156_preds.json
# ✅ Copiato:
#   vslnet_198_128355_preds.json → vslbase_198_128355_preds.json
# ✅ Copiato:
#   vslnet_199_128478_preds.json → vslbase_199_128478_preds.json
# ✅ Copiato:
#   vslnet_199_128800_preds.json → vslbase_199_128800_preds.json
# ✅ Copiato:
#   vslnet_199_129000_preds.json → vslbase_199_129000_preds.json

# %%
# @title Selezione del miglior file di predizione per VSLBase e Net
gt_lookup = load_gt(gt_path)
best_vslnet = evaluate_predictions(pred_dir_vslnet, gt_lookup)
best_vslbase = evaluate_predictions(pred_dir_vslbase, gt_lookup)

print("\n📌 VSLNet miglior file:", best_vslnet)
print("📌 VSLBase miglior file:", best_vslbase)

# SELEZIONO I MIGLIORI PREDS FILE (sono individuati dal modello stesso)
#best_vslnet2 = "/content/drive/MyDrive/training/training_best_200_GLOVE_vslnet_egovlp/egovlp_fp16/vslnet_nlq_official_v1_egovlp_fp16_official_128_glove/model/vslnet_74_48300_preds.json"
df_vslnet = build_dataframe(best_vslnet, gt_lookup)
#best_vslbase2 = "/content/drive/MyDrive/training/training_best_200_GLOVE_vslbase_egovlp/checkpoints/egovlp_fp16/vslbase_nlq_official_v1_egovlp_fp16_official_128_glove/model/vslbase_129_83398_preds.json"
df_vslbase = build_dataframe(best_vslbase, gt_lookup)
# Out:
# 📌 VSLNet miglior file: /content/drive/MyDrive/training_best_200_GLOVE_vslnet_egovlp_onlytrain/egovlp_fp16/vslnet_nlq_official_v1_egovlp_fp16_official_128_glove/model/vslnet_74_48300_preds.json
# 📌 VSLBase miglior file: /content/drive/MyDrive/training/training_best_200_GLOVE_vslbase_egovlp/checkpoints/egovlp_fp16/vslbase_nlq_official_v1_egovlp_fp16_official_128_glove/model/vslbase_129_83398_preds.json

# %%
print(gt_lookup)
print(df_vslnet)
print(df_vslbase)
# Out:
# {('93231c7e-1cf4-4a20-b1f8-9cc9428915b2', 'ca7e11a2-cd1e-40dd-9d2f-ea810ab6a99b', 0): {'video_uid': '38737402-19bd-4689-9e74-3af391b15feb', 'gt_start': 425.0, 'gt_end': 431.0, 'query': 'what did I put in the black dustbin?', 'template': 'Objects: What did I put in X?', 'clip_start_sec': 630.0}, ('93231c7e-1cf4-4a20-b1f8-9cc9428915b2', 'ca7e11a2-cd1e-40dd-9d2f-ea810ab6a99b', 1): {'video_uid': '38737402-19bd-4689-9e74-3af391b15feb', 'gt_start': 465.0, 'gt_end': 472.0, 'query': 'who did I talk to in  the house?', 'template': 'People: Who did I talk to in location X?', 'clip_start_sec': 630.0}, ('93231c7e-1cf4-4a20-b1f8-9cc9428915b2', 'ca7e11a2-cd1e-40dd-9d2f-ea810ab6a99b', 2): {'video_uid': '38737402-19bd-4689-9e74-3af391b15feb', 'gt_start': 173.9, 'gt_end': 174.0, 'query': 'In what location did I see white dustbin?', 'template': 'Objects: In what location did I see object X ?', 'clip_start_sec': 630.0}, ('93231c7e-1cf4-4a20-b1f8-9cc9428915b2', 'ca7e11a2-cd1e-40dd-9d2f-ea810ab6a99b', 3): {'video_uid': '38737402-19bd-4689-9e74-3af391b15feb', 'gt_start': 178.0, 'gt_end': 184.0, 'query': 'where did I put carton?', 'template': 'Place: Where did I put X?', 'clip_start_sec': 630.0}, ('93231c7e-1cf4-4a20-b1f8-9cc9428915b2', '73e357da-b5c3-4b83-8bc8-d80129cbc46b', 0): {'video_uid': '38737402-19bd-4689-9e74-3af391b15feb', 'gt_start': 384.0, 'gt_end': 393.067, 'query': 'Who did I interact with when I played with the dog for the second time in the living room?', 'template': 'People: Who did I interact with when I did activity X?', 'clip_start_sec': 630.0}, ('93231c7e-1cf4-4a20-b1f8-9cc9428915b2', '73e357da-b5c3-4b83-8bc8-d80129cbc46b', 1): {'video_uid': '38737402-19bd-4689-9e74-3af391b15feb', 'gt_start': 444.067, 'gt_end': 452.267, 'query': 'Where did I put the vacuum cleaner head?', 'template': 'Place: Where did I put X?', 'clip_start_sec': 630.0}, ('93231c7e-1cf4-4a20-b1f8-9cc9428915b2', '73e357da-b5c3-4b83-8bc8-d80129cbc46b', 2): {'video_uid': '38737402-19bd-4689-9e74-3af391b15feb', 'gt_start': 210.0, 'gt_end': 217.0, 'query': 'Where was vacuum cleaner before I used it for the first time?', 'template': 'Objects: Where is object X before / after event Y?', 'clip_start_sec': 630.0}, ('93231c7e-1cf4-4a20-b1f8-9cc9428915b2', '73e357da-b5c3-4b83-8bc8-d80129cbc46b', 3): {'video_uid': '38737402-19bd-4689-9e74-3af391b15feb', 'gt_start': 141.0, 'gt_end': 142.367, 'query': 'Where did I put the phone?', 'template': 'Place: Where did I put X?', 'clip_start_sec': 630.0}, ('93231c7e-1cf4-4a20-b1f8-9cc9428915b2', '73e357da-b5c3-4b83-8bc8-d80129cbc46b', 4): {'video_uid': '38737402-19bd-4689-9e74-3af391b15feb', 'gt_start': 172.0, 'gt_end': 174.6, 'query': 'Where was the trash can before I raised it?', 'template': 'Objects: Where is object X before / after event Y?', 'clip_start_sec': 630.0}, ('93231c7e-1cf4-4a20-b1f8-9cc9428915b2', '73e357da-b5c3-4b83-8bc8-d80129cbc46b', 5): {'video_uid': '38737402-19bd-4689-9e74-3af391b15feb', 'gt_start': 73.0, 'gt_end': 75.8, 'query': 'Where did I put the pink and white towel?', 'template': 'Place: Where did I put X?', 'clip_start_sec': 630.0}, ('93231c7e-1cf4-4a20-b1f8-9cc9428915b2', '73e357da-b5c3-4b83-8bc8-d80129cbc46b', 6): {'video_uid': '38737402-19bd-4689-9e74-3af391b15feb', 'gt_start': 67.0, 'gt_end': 71.0, 'query': 'Where was the phone before I picked it up for the first time in the bedroom?', 'template': 'Objects: Where is object X before / after event Y?', 'clip_start_sec': 630.0}, ('93231c7e-1cf4-4a20-b1f8-9cc9428915b2', '73e357da-b5c3-4b83-8bc8-d80129cbc46b', 7): {'video_uid': '38737402-19bd-4689-9e74-3af391b15feb', 'gt_start': 125.0, 'gt_end': 141.267, 'query': 'In what location did I press the phone last?', 'template': 'Objects: In what location did I see object X ?', 'clip_start_sec': 630.0}, ('75d3fc52-3776-47d4-b7fd-8074d30b06d1', '93891b44-c00f-43d9-885b-92fdce39128c', 0): {'video_uid': '413fe086-1745-4573-b75b-e7d26ff72df9', 'gt_start': 3.319, 'gt_end': 4.619, 'query': 'Where did I put the chopsticks ...
#                                   clip_uid  \
# 0     93231c7e-1cf4-4a20-b1f8-9cc9428915b2
# 1     93231c7e-1cf4-4a20-b1f8-9cc9428915b2
# 2     93231c7e-1cf4-4a20-b1f8-9cc9428915b2
# 3     93231c7e-1cf4-4a20-b1f8-9cc9428915b2
# 4     93231c7e-1cf4-4a20-b1f8-9cc9428915b2
# ...                                    ...
# 3869  bfea3e01-55f4-4744-a7c6-4494c7b99ef2
# 3870  bfea3e01-55f4-4744-a7c6-4494c7b99ef2
# 3871  bfea3e01-55f4-4744-a7c6-4494c7b99ef2
# 3872  bfea3e01-55f4-4744-a7c6-4494c7b99ef2
# 3873  bfea3e01-55f4-4744-a7c6-4494c7b99ef2
#
#                             annotation_uid  query_idx  \
# 0     ca7e11a2-cd1e-40dd-9d2f-ea810ab6a99b          0
# 1     ca7e11a2-cd1e-40dd-9d2f-ea810ab6a99b          1
# 2     ca7e11a2-cd1e-40dd-9d2f-ea810ab6a99b          2
# 3     ca7e11a2-cd1e-40dd-9d2f-ea810ab6a99b          3
# 4     73e357da-b5c3-4b83-8bc8-d80129cbc46b          0
# ...                                    ...        ...
# 3869  a60f6dff-a926-4182-b5ca-adf421c077d4          0
# 3870  a60f6dff-a926-4182-b5ca-adf421c077d4          1
# 3871  a60f6dff-a926-4182-b5ca-adf421c077d4          2
# 3872  a60f6dff-a926-4182-b5ca-adf421c077d4          3
# 3873  a60f6dff-a926-4182-b5ca-adf421c077d4          4
#
#                                  video_uid  \
# 0     38737402-19bd-4689-9e74-3af391b15feb
# 1     38737402-19bd-4689-9e74-3af391b15feb
# 2     38737402-19bd-4689-9e74-3af391b15feb
# 3     38737402-19bd-4689-9e74-3af391b15feb
# 4     38737402-19bd-4689-9e74-3af391b15feb
# ...                                    ...
# 3869  000cd456-ff8d-499b-b0c1-4acead128a8b
# 3870  000cd456-ff8d-499b-b0c1-4acead128a8b
# 3871  000cd456-ff8d-499b-b0c1-4acead128a8b
# 3872  000cd456-ff8d-499b-b0c1-4acead128a8b
# 3873  000cd456-ff8d-499b-b0c1-4acead128a8b
#
#                                                template  \
# 0                         Objects: What did I put in X?
# 1              People: Who did I talk to in location X?
# 2        Objects: In what location did I see object X ?
# 3                             Place: Where did I put X?
# 4     People: Who did I interact with when I did act...
# ...                                                 ...
# 3869  Objects: Where is object X before / after even...
# 3870  Objects: Where is object X before / after even...
# 3871           People: Who did I talk to in location X?
# 3872                      Objects: What did I put in X?
# 3873  Objects: Where is object X before / after even...
#
#                                                   query   gt_start     gt_end  \
# 0                  what did I put in the black dustbin?  425.00000  431.00000
# 1                      who did I talk to in  the house?  465.00000  472.00000
# 2             In what location did I see white dustbin?  173.90000  174.00000
# 3                               where did I put carton?  178.00000  184.00000
# 4     Who did I interact with when I played with the...  384.00000  393.06700
# ...                                                 ...        ...        ...
# 3869  Where was the bottle before i threw it on the ...  183.30142  194.42204
# 3870         where was the trolley before i dragged it?  250.87701  252.77154
# 3871                    who did i talk to in the house?  397.99761  407.86223
# 3872                     what did i put in the trolley?  184.65552  186.67746
# 3873  where was the custom plastic ball before i kic...  218.04649  226.40885
#
#       pred_start    pred_end       iou     iou@1     iou@5    gt_len  \
# 0      52.500000  438.750000  0.015534  0.015534  0.400000   6.00000
# 1     465.000000  476.250000  0.622222  0.622222  0.933333   7.00000
# 2     435.000000  438.750000  0.000000  0.000000  0.000259   0.10000
# 3     423.750000  435.000000  0.000000  0.000000  0.018605   6.00000
# 4     465.000000  468.750000  0.000000  0.000000  0.241787   9.06700
# ...          ...         ...       ...       ...       ...       ...
# 3869  183.545837  191.037506  0.673674  0.673674  0.673674  11.12062
# 3870    0.000000    3.745833  0.000000  0.000000  0.000000   1.89453
# 3871    0.000000  213.512497  0.000000  0.000000  0.000000   9.86462
# 3872    0.000000    3.745833  0.000000  0.000000  0.010796   2.02194
# 3873    0.000000    3.745833  0.000000  0.000000  0.036597   8.36236
#
#         pred_len  length_error
# 0     386.250000    380.250000
# 1      11.250000      4.250000
# 2       3.750000      3.650000
# 3      11.250000      5.250000
# 4       3.750000     -5.317000
# ...          ...           ...
# 3869    7.491669     -3.628951
# 3870    3.745833      1.851303
# 3871  213.512497    203.647877
# 3872    3.745833      1.723893
# 3873    3.745833     -4.616527
#
# [3874 rows x 16 columns]
#                                   clip_uid  \
# 0     93231c7e-1cf4-4a20-b1f8-9cc9428915b2
# 1     93231c7e-1cf4-4a20-b1f8-9cc9428915b2
# 2     93231c7e-1cf4-4a20-b1f8-9cc9428915b2
# 3     93231c7e-1cf4-4a20-b1f8-9cc9428915b2
# 4     93231c7e-1cf4-4a20-b1f8-9cc9428915b2
# ...                                    ...
# 3524  bfea3e01-55f4-4744-a7c6-4494c7b99ef2
# 3525  bfea3e01-55f4-4744-a7c6-4494c7b99ef2
# 3526  bfea3e01-55f4-4744-a7c6-4494c7b99ef2
# 3527  bfea3e01-55f4-4744-a7c6-4494c7b99ef2
# 3528  bfea3e01-55f4-4744-a7c6-4494c7b99ef2
#
#                             annotation_uid  query_idx  \
# 0     ca7e11a2-cd1e-40dd-9d2f-ea810ab6a99b          0
# 1     ca7e11a2-cd1e-40dd-9d2f-ea810ab6a99b          1
# 2     ca7e11a2-cd1e-40dd-9d2f-ea810ab6a99b          2
# 3     ca7e11a2-cd1e-40dd-9d2f-ea810ab6a99b          3
# 4     73e357da-b5c3-4b83-8bc8-d80129cbc46b          0
# ...                                    ...        ...
# 3524  a60f6dff-a926-4182-b5ca-adf421c077d4          0
# 3525  a60f6dff-a926-4182-b5ca-adf421c077d4          1
# 3526  a60f6dff-a926-4182-b5ca-adf421c077d4          2
# 3527  a60f6dff-a926-4182-b5ca-adf421c077d4          3
# 3528  a60f6dff-a926-4182-b5ca-adf421c077d4          4
#
#                                  video_uid  \
# 0     38737402-19bd-4689-9e74-3af391b15feb
# 1     38737402-19bd-4689-9e74-3af391b15feb
# 2     38737402-19bd-4689-9e74-3af391b15feb
# 3     38737402-19bd-4689-9e74-3af391b15feb
# 4     38737402-19bd-4689-9e74-3af391b15feb
# ...                                    ...
# 3524  000cd456-ff8d-499b-b0c1-4acead128a8b
# 3525  000cd456-ff8d-499b-b0c1-4acead128a8b
# 3526  000cd456-ff8d-499b-b0c1-4acead128a8b
# 3527  000cd456-ff8d-499b-b0c1-4acead128a8b
# 3528  000cd456-ff8d-499b-b0c1-4acead128a8b
#
#                                                template  \
# 0                         Objects: What did I put in X?
# 1              People: Who did I talk to in location X?
# 2        Objects: In what location did I see object X ?
# 3                             Place: Where did I put X?
# 4     People: Who did I interact with when I did act...
# ...                                                 ...
# 3524  Objects: Where is object X before / after even...
# 3525  Objects: Where is object X before / after even...
# 3526           People: Who did I talk to in location X?
# 3527                      Objects: What did I put in X?
# 3528  Objects: Where is object X before / after even...
#
#                                                   query   gt_start     gt_end  \
# 0                  what did I put in the black dustbin?  425.00000  431.00000
# 1                      who did I talk to in  the house?  465.00000  472.00000
# 2             In what location did I see white dustbin?  173.90000  174.00000
# 3                               where did I put carton?  178.00000  184.00000
# 4     Who did I interact with when I played with the...  384.00000  393.06700
# ...                                                 ...        ...        ...
# 3524  Where was the bottle before i threw it on the ...  183.30142  194.42204
# 3525         where was the trolley before i dragged it?  250.87701  252.77154
# 3526                    who did i talk to in the house?  397.99761  407.86223
# 3527                     what did i put in the trolley?  184.65552  186.67746
# 3528  where was the custom plastic ball before i kic...  218.04649  226.40885
#
#       pred_start    pred_end       iou     iou@1     iou@5    gt_len  \
# 0      52.500000   56.250000  0.000000  0.000000  0.000000   6.00000
# 1      52.500000  480.000000  0.016374  0.016374  0.466667   7.00000
# 2     423.750000  431.250000  0.000000  0.000000  0.000000   0.10000
# 3     435.000000  438.750000  0.000000  0.000000  0.022222   6.00000
# 4     367.500000  371.250000  0.000000  0.000000  0.345410   9.06700
# ...          ...         ...       ...       ...       ...       ...
# 3524  213.512497  221.004166  0.000000  0.000000  0.050319  11.12062
# 3525    0.000000    3.745833  0.000000  0.000000  0.000000   1.89453
# 3526  209.766663  213.512497  0.000000  0.000000  0.000000   9.86462
# 3527    0.000000  228.495834  0.008849  0.008849  0.010584   2.02194
# 3528    0.000000  213.512497  0.000000  0.000000  0.446488   8.36236
#
#         pred_len  length_error
# 0       3.750000     -2.250000
# 1     427.500000    420.500000
# 2       7.500000      7.400000
# 3       3.750000     -2.250000
# 4       3.750000     -5.317000
# ...          ...           ...
# 3524    7.491669     -3.628951
# 3525    3.745833      1.851303
# 3526    3.745834     -6.118786
# 3527  228.495834    226.473894
# 3528  213.512497    205.150137
#
# [3529 rows x 16 columns]

# %%
# @title Verifico che effettivamente le query in bad keys abbiamo IoU <0.1
def check_bad_keys_have_zero_iou(df, bad_keys):
    # Filtra solo le righe del dataframe i cui identificatori sono nei bad_keys
    df_bad = df[df.apply(lambda row: (row["clip_uid"], row["annotation_uid"], row["query_idx"]) in bad_keys, axis=1)]

    # Trova le righe in cui la iou è >0.1
    df_non_zero_iou = df_bad[df_bad["iou"] > 0.1]

    if not df_non_zero_iou.empty:
        print("⚠️ Alcuni bad_keys hanno iou diversa da zero:")
        print(df_non_zero_iou[["clip_uid", "annotation_uid", "query_idx", "iou"]])
    else:
        print("✅ Tutti i bad_keys hanno iou < 0.1 come previsto.")

check_bad_keys_have_zero_iou(df_vslbase, bad_keys)
check_bad_keys_have_zero_iou(df_vslnet, bad_keys)
# Out:
# ✅ Tutti i bad_keys hanno iou < 0.1 come previsto.
# ✅ Tutti i bad_keys hanno iou < 0.1 come previsto.

# %%
# Rimuovo bad keys
def remove_bad_keys(df, bad_keys):
    return df[~df.apply(lambda row: (row["clip_uid"], row["annotation_uid"], row["query_idx"]) in bad_keys, axis=1)]
df_vslbase = remove_bad_keys(df_vslbase, bad_keys)
df_vslnet = remove_bad_keys(df_vslnet, bad_keys)

# %%
# Quanti elementi ci sono nel ground truth?
print("Numero di coppie (clip, annotation, query) nel GT:", len(gt_lookup))

# Quanti record stai effettivamente valutando?
print("Record con almeno una predizione valida:")
print("  VSLBase:", len(df_vslbase))
print("  VSLNet: ", len(df_vslnet))


# Conteggi per TUTTI i bin [0.0–0.1), [0.1–0.2), …, [0.9–1.0)
all_bins = np.linspace(0, 1, 11)
counts_base_all, _ = np.histogram(df_vslbase["iou"], bins=all_bins)
counts_net_all,  _ = np.histogram(df_vslnet["iou"],  bins=all_bins)

print("\nConteggi completi per ogni intervallo di IoU:")
for left, right, cb, cn in zip(all_bins[:-1], all_bins[1:], counts_base_all, counts_net_all):
    print(f"[{left:.1f}, {right:.1f}) -> VSLBase: {cb}, VSLNet: {cn}")
# Out:
# Numero di coppie (clip, annotation, query) nel GT: 3874
# Record con almeno una predizione valida:
#   VSLBase: 3529
#   VSLNet:  3529
#
# Conteggi completi per ogni intervallo di IoU:
# [0.0, 0.1) -> VSLBase: 3031, VSLNet: 2981
# [0.1, 0.2) -> VSLBase: 136, VSLNet: 132
# [0.2, 0.3) -> VSLBase: 93, VSLNet: 98
# [0.3, 0.4) -> VSLBase: 71, VSLNet: 89
# [0.4, 0.5) -> VSLBase: 51, VSLNet: 50
# [0.5, 0.6) -> VSLBase: 52, VSLNet: 56
# [0.6, 0.7) -> VSLBase: 30, VSLNet: 47
# [0.7, 0.8) -> VSLBase: 37, VSLNet: 37
# [0.8, 0.9) -> VSLBase: 15, VSLNet: 23
# [0.9, 1.0) -> VSLBase: 13, VSLNet: 16

# %% [markdown]
# NOTA: Qui le query con window_lenght nulla nel val sono tolte già durante il training!! non servono le celle legate a bad_keys

# %%
# @title Plot e tabelle per l'analisi dei risultati ottenuti

# Plot Moment Length Error
plot_length_error_comparison_lines(df_vslbase, df_vslnet, "VSLBase", "VSLNet", os.path.join(output_dir, "moment_length_error.png"))

# Plot Istogramma IoU
plot_iou_histogram_comparison(
    df_vslbase,
    df_vslnet,
    "VSLBase",
    "VSLNet",
    os.path.join(output_dir, "iou_histogram")
)

# Tabella riassuntiva
build_results_table(
    data_list=[
        (df_vslbase, "VSLBase", "EgoVLP"),
        (df_vslnet, "VSLNet", "EgoVLP"),
    ],
    output_path=os.path.join(output_dir, "tabella_riassuntiva_egovlp.png")
)

# Plotta 5 clip significativi
cinque_casi = seleziona_casi_specifici(df_vslbase, df_vslnet)
plot_cinque_casi_riformattato(cinque_casi, os.path.join(output_dir, "cinque_casi_rappresentativi.png"))

# %% [markdown]
# Moment Lenght Error (da articolo 4)\\
# Viene misurata la differenza tra la lunghezza dei momenti predetti e il ground truth. Una differenza di lunghezza positiva indica che il momento predetto è più lungo del ground truth corrispondente, mentre una lunghezza negativa il contrario. Nella figura si vede che VSLBase tende a predire momenti più lunghi, mentre al contrario VSLNet, vincolato da QGH, tende a predire momenti più corti.
#
#
# Istogramma IoU \\
# La figura mostra gli istrogrammi dei risultati predetti sul validation set.
# VSLNet presenta più campioni per gli IoU più altri, quindi per esempio IoU >= 0.7. Questo dimostra l'efficacia della strategia QGH.
#
#
# Tabella riassuntiva
# VSLNet + Omnivore il migliore in ogni caso

# %%
# Dedurre da qui info su video_uid e iou per i 5 casi rappresentativi
print(cinque_casi)
# Out:
# {'best_net': clip_uid_net                        5d531ac1-010a-4e67-ba1a-96e485b14968
# annotation_uid_net                  3eb83361-fc41-4f9c-bb0c-978bebbf1175
# query_idx_net                                                          0
# video_uid_net                       f082242c-309f-48a1-97fa-5c1d6bd255fb
# template_net                                    Objects: What X did I Y?
# query_net                                   What vegetables did I chop?
# gt_start_net                                                         0.0
# gt_end_net                                                          38.0
# pred_start_net                                                       0.0
# pred_end_net                                                        37.5
# iou_net                                                         0.986842
# iou@1_net                                                       0.986842
# iou@5_net                                                       0.986842
# gt_len_net                                                          38.0
# pred_len_net                                                        37.5
# length_error_net                                                    -0.5
# key                    (5d531ac1-010a-4e67-ba1a-96e485b14968, 3eb8336...
# clip_uid_base                       5d531ac1-010a-4e67-ba1a-96e485b14968
# annotation_uid_base                 3eb83361-fc41-4f9c-bb0c-978bebbf1175
# query_idx_base                                                         0
# video_uid_base                      f082242c-309f-48a1-97fa-5c1d6bd255fb
# template_base                                   Objects: What X did I Y?
# query_base                                  What vegetables did I chop?
# gt_start_base                                                        0.0
# gt_end_base                                                         38.0
# pred_start_base                                                      0.0
# pred_end_base                                                       37.5
# iou_base                                                        0.986842
# iou@1_base                                                      0.986842
# iou@5_base                                                      0.986842
# gt_len_base                                                         38.0
# pred_len_base                                                       37.5
# length_error_base                                                   -0.5
# Name: 3123, dtype: object, 'best_base': clip_uid_net                        5d531ac1-010a-4e67-ba1a-96e485b14968
# annotation_uid_net                  3eb83361-fc41-4f9c-bb0c-978bebbf1175
# query_idx_net                                                          0
# video_uid_net                       f082242c-309f-48a1-97fa-5c1d6bd255fb
# template_net                                    Objects: What X did I Y?
# query_net                                   What vegetables did I chop?
# gt_start_net                                                         0.0
# gt_end_net                                                          38.0
# pred_start_net                                                       0.0
# pred_end_net                                                        37.5
# iou_net                                                         0.986842
# iou@1_net                                                       0.986842
# iou@5_net                                                       0.986842
# gt_len_net                                                          38.0
# pred_len_net                                                        37.5
# length_error_net                                                    -0.5
# key                    (5d531ac1-010a-4e67-ba1a-96e485b14968, 3eb8336...
# clip_uid_base                       5d531ac1-010a-4e67-ba1a-96e485b14968
# annotation_uid_base                 3eb83361-fc41-4f9c-bb0c-978bebbf1175
# query_idx_base                                                         0
# video_uid_base                      f082242c-309f-48a1-97fa-5c1d6bd255fb
# template_base                                   Objects: What X did I Y?
# query_base                                  What vegetables did I chop?
# gt_start_base                                                        0.0
# gt_end_base                                                         38.0
# pred_start_base                                                      0.0
# pred_end_base                                                       37.5
# iou_base                                                        0.986842
# iou@1_base                                                      0.986842
# iou@5_base                                                      0.986842
# gt_len_base                                                         38.0
# pred_len_base                                                       37.5
# length_error_base                                                   -0.5
# Name: 3123, dtype: object, 'worst_net': clip_uid_net                        93231c7e-1cf4-4a20-b1f8-9cc9428915b2
# annotation_uid_net                  ca7e11a2-cd1e-40dd-9d2f-ea810ab6a99b
# query_idx_net                                                          2
# video_uid_net                       38737402-19bd-4689-9e74-3af391b15feb
# template_net              Objects: In what location did I see object X ?
# query_net                      In what location did I see white dustbin?
# gt_start_net                                                       173.9
# gt_end_net                                                         174.0
# pred_start_net                                                     435.0
# pred_end_net                                                      438.75
# iou_net                                                              0.0
# iou@1_net                                                            0.0
# iou@5_net                                                       0.000259
# gt_len_net                                                           0.1
# pred_len_net                                                        3.75
# length_error_net                                                    3.65
# key                    (93231c7e-1cf4-4a20-b1f8-9cc9428915b2, ca7e11a...
# clip_uid_base                       93231c7e-1cf4-4a20-b1f8-9cc9428915b2
# annotation_uid_base                 ca7e11a2-cd1e-40dd-9d2f-ea810ab6a99b
# query_idx_base                                                         2
# video_uid_base                      38737402-19bd-4689-9e74-3af391b15feb
# template_base             Objects: In what location did I see object X ?
# query_base                     In what location did I see white dustbin?
# gt_start_base                                                      173.9
# gt_end_base                                                        174.0
# pred_start_base                                                   423.75
# pred_end_base                                                     431.25
# iou_base                                                             0.0
# iou@1_base                                                           0.0
# iou@5_base                                                           0.0
# gt_len_base                                                          0.1
# pred_len_base                                                        7.5
# length_error_base                                                    7.4
# Name: 2, dtype: object, 'worst_base': clip_uid_net                        93231c7e-1cf4-4a20-b1f8-9cc9428915b2
# annotation_uid_net                  ca7e11a2-cd1e-40dd-9d2f-ea810ab6a99b
# query_idx_net                                                          0
# video_uid_net                       38737402-19bd-4689-9e74-3af391b15feb
# template_net                               Objects: What did I put in X?
# query_net                           what did I put in the black dustbin?
# gt_start_net                                                       425.0
# gt_end_net                                                         431.0
# pred_start_net                                                      52.5
# pred_end_net                                                      438.75
# iou_net                                                         0.015534
# iou@1_net                                                       0.015534
# iou@5_net                                                            0.4
# gt_len_net                                                           6.0
# pred_len_net                                                      386.25
# length_error_net                                                  380.25
# key                    (93231c7e-1cf4-4a20-b1f8-9cc9428915b2, ca7e11a...
# clip_uid_base                       93231c7e-1cf4-4a20-b1f8-9cc9428915b2
# annotation_uid_base                 ca7e11a2-cd1e-40dd-9d2f-ea810ab6a99b
# query_idx_base                                                         0
# video_uid_base                      38737402-19bd-4689-9e74-3af391b15feb
# template_base                              Objects: What did I put in X?
# query_base                          what did I put in the black dustbin?
# gt_start_base                                                      425.0
# gt_end_base                                                        431.0
# pred_start_base                                                     52.5
# pred_end_base                                                      56.25
# iou_base                                                             0.0
# iou@1_base                                                           0.0
# iou@5_base                                                           0.0
# gt_len_base                                                          6.0
# pred_len_base                                                       3.75
# length_error_base                                                  -2.25
# Name: 0, dtype: object, 'net_better': clip_uid_net                        2276090d-3aab-4a4f-afbe-dcc083604160
# annotation_uid_net                  7fd6377f-dfe7-41fa-ad2a-9218e194a58f
# query_idx_net                                                          4
# video_uid_net                       224c3de4-9683-462a-8eb4-224773425a7e
# template_net                                    Objects: What X did I Y?
# query_net                                          What food did I stir?
# gt_start_net                                                   139.78435
# gt_end_net                                                         230.0
# pred_start_net                                                    138.75
# pred_end_net                                                       232.5
# iou_net                                                           0.9623
# iou@1_net                                                         0.9623
# iou@5_net                                                         0.9623
# gt_len_net                                                      90.21565
# pred_len_net                                                       93.75
# length_error_net                                                 3.53435
# key                    (2276090d-3aab-4a4f-afbe-dcc083604160, 7fd6377...
# clip_uid_base                       2276090d-3aab-4a4f-afbe-dcc083604160
# annotation_uid_base                 7fd6377f-dfe7-41fa-ad2a-9218e194a58f
# query_idx_base                                                         4
# video_uid_base                      224c3de4-9683-462a-8eb4-224773425a7e
# template_base                                   Objects: What X did I Y?
# query_base                                         What food did I stir?
# gt_start_base                                                  139.78435
# gt_end_base                                                        230.0
# pred_start_base                                                     45.0
# pred_end_base                                                      78.75
# iou_base                                                             0.0
# iou@1_base                                                           0.0
# iou@5_base                                                      0.480895
# gt_len_base                                                     90.21565
# pred_len_base                                                      33.75
# length_error_base                                              -56.46565
# diff_net_base                                                     0.9623
# Name: 3156, dtype: object}

# %%
# Filtra le predizioni con IoU molto bassa
low_iou_vslnet = df_vslnet[(df_vslnet["iou"] >= 0.0) & (df_vslnet["iou"] <= 0.1)]
low_iou_vslbase = df_vslbase[(df_vslbase["iou"] >= 0.0) & (df_vslbase["iou"] <= 0.1)]
for i, row in low_iou_vslnet.head(5).iterrows():
    print(f"🔹 Query: {row['query']}")
    print(f"  GT:     {row['gt_start']:.2f} - {row['gt_end']:.2f} ({row['gt_len']:.2f}s)")
    print(f"  Pred:   {row['pred_start']:.2f} - {row['pred_end']:.2f} ({row['pred_len']:.2f}s)")
    print(f"  IoU:    {row['iou']:.4f}")
    print(f"  Error Length: {row['length_error']:.2f}\n")

for i, row in low_iou_vslbase.head(5).iterrows():
    print(f"🔹 Query: {row['query']}")
    print(f"  GT:     {row['gt_start']:.2f} - {row['gt_end']:.2f} ({row['gt_len']:.2f}s)")
    print(f"  Pred:   {row['pred_start']:.2f} - {row['pred_end']:.2f} ({row['pred_len']:.2f}s)")
    print(f"  IoU:    {row['iou']:.4f}")
    print(f"  Error Length: {row['length_error']:.2f}\n")
# Out:
# 🔹 Query: what did I put in the black dustbin?
#   GT:     425.00 - 431.00 (6.00s)
#   Pred:   52.50 - 438.75 (386.25s)
#   IoU:    0.0155
#   Error Length: 380.25
#
# 🔹 Query: In what location did I see white dustbin?
#   GT:     173.90 - 174.00 (0.10s)
#   Pred:   435.00 - 438.75 (3.75s)
#   IoU:    0.0000
#   Error Length: 3.65
#
# 🔹 Query: where did I put carton?
#   GT:     178.00 - 184.00 (6.00s)
#   Pred:   423.75 - 435.00 (11.25s)
#   IoU:    0.0000
#   Error Length: 5.25
#
# 🔹 Query: Who did I interact with when I played with the dog for the second time in the living room?
#   GT:     384.00 - 393.07 (9.07s)
#   Pred:   465.00 - 468.75 (3.75s)
#   IoU:    0.0000
#   Error Length: -5.32
#
# 🔹 Query: Where did I put the vacuum cleaner head?
#   GT:     444.07 - 452.27 (8.20s)
#   Pred:   423.75 - 435.00 (11.25s)
#   IoU:    0.0000
#   Error Length: 3.05
#
# 🔹 Query: what did I put in the black dustbin?
#   GT:     425.00 - 431.00 (6.00s)
#   Pred:   52.50 - 56.25 (3.75s)
#   IoU:    0.0000
#   Error Length: -2.25
#
# 🔹 Query: who did I talk to in  the house?
#   GT:     465.00 - 472.00 (7.00s)
#   Pred:   52.50 - 480.00 (427.50s)
#   IoU:    0.0164
#   Error Length: 420.50
#
# 🔹 Query: In what location did I see white dustbin?
#   GT:     173.90 - 174.00 (0.10s)
#   Pred:   423.75 - 431.25 (7.50s)
#   IoU:    0.0000
#   Error Length: 7.40
#
# 🔹 Query: where did I put carton?
#   GT:     178.00 - 184.00 (6.00s)
#   Pred:   435.00 - 438.75 (3.75s)
#   IoU:    0.0000
#   Error Length: -2.25
#
# 🔹 Query: Who did I interact with when I played with the dog for the second time in the living room?
#   GT:     384.00 - 393.07 (9.07s)
#   Pred:   367.50 - 371.25 (3.75s)
#   IoU:    0.0000
#   Error Length: -5.32

# %%
# @title Exam failure cases

# Seleziono query con iou basso per vsl net
low_iou_vslnet = df_vslnet[(df_vslnet["iou"] >= 0.0) & (df_vslnet["iou"] <= 0.1)]
# Seleziono query con iou basso per vsl base
low_iou_vslbase = df_vslbase[(df_vslbase["iou"] >= 0.0) & (df_vslbase["iou"] <= 0.1)]

# Crea set di chiavi identificative
low_keys_vslnet = set(zip(low_iou_vslnet["clip_uid"], low_iou_vslnet["annotation_uid"], low_iou_vslnet["query_idx"]))
low_keys_vslbase = set(zip(low_iou_vslbase["clip_uid"], low_iou_vslbase["annotation_uid"], low_iou_vslbase["query_idx"]))

# Intersezione: query con IoU ≤ 0.1 in entrambi i modelli
low_keys_common = low_keys_vslnet.intersection(low_keys_vslbase)
# Stampo il numero di casi che falliscono per entrambi
print(len(low_keys_common))

# Creo dataframe con quei casi (prendo vsl net perchè tanto l'info sul template che mi serve dopo non cambia tra base e net)
low_common_df = df_vslnet[df_vslnet.apply(lambda row: (row["clip_uid"], row["annotation_uid"], row["query_idx"]) in low_keys_common, axis=1)]


plt.figure(figsize=(10, 6))
sns.countplot(data=low_common_df, y="template", order=low_common_df["template"].value_counts().index)
plt.title("Query with IoU ≤ 0.1 in both VSLNet and VSLBase, group by template")
plt.xlabel("Number of queries")
plt.ylabel("Template")
plt.tight_layout()
plt.show()
# Out:
# 2727

# %% [markdown]
# Da questo plot emerge che i modelli hanno le performance comunemente peggiori su specifiche tipologie di query. In particolare, i modelli fanno più difficoltà a predire correttamente le query associate ai template "Place: Where I did put X", "Where is object X before/ after event Y?", Where is object X?, What did I put in X? Che erano le tipologie di query che erano risultate essere associate a finestre di risposta più strette durante l'esplorazione del dataset iniziale.

# %%
# Confronto con uno scatter plot come sono gli andamenti dei due modelli. Sulla diagonale ci sono le query azzeccate da entrambi, sopra quelle di vslnet, sotto quelle da vslbase

plt.figure(figsize=(6,6))
plt.scatter(df_vslbase["iou"], df_vslnet["iou"], alpha=0.7)
plt.xlabel("IoU VSLBase")
plt.ylabel("IoU VSLNet")
plt.title("IoU VSLBase vs VSLNet")
plt.plot([0,1], [0,1], '--', color='gray')
plt.grid()
plt.show()

# %% [markdown]
# GUIDA PER LEGGERE IL GRAFICO
# Asse X: IoU ottenuto da VSLBase
# Asse Y: IoU ottenuto da VSLNet
# Ogni punto rappresenta una singola query su cui entrambi i modelli sono stati valutati.
#
# Diagonale tratteggiata (y = x) Punti sulla diagonale → i due modelli hanno ottenuto lo stesso IoU su quella query. Punti sopra la diagonale → VSLNet ha performato meglio (IoU più alto). Punti sotto la diagonale → VSLBase ha performato meglio.
#
# INTERPRETAZIONE
#
# Prevalenza di punti sopra la diagonale Conferma che VSLNet è un miglioramento effettivo del modello base.
#
# Densità vicino allo 0 (in basso a sinistra) Molte query hanno IoU ≈ 0 per entrambi i modelli, quindi non sono state predette correttamente da nessuno dei due. Questo può indicare: Query particolarmente ambigue o difficili. Clip troppo brevi/lunghe o query poco informative.
#
# Punti sul bordo sinistro (x ≈ 0, y > 0) VSLBase fallisce completamente (IoU ≈ 0), ma VSLNet riesce a predire bene → forte miglioramento.
#
# Punti sul bordo inferiore (y ≈ 0, x > 0) Rari nel tuo caso → conferma che VSLBase raramente supera VSLNet.

# %%
# @title Indaghiamo gli andamenti dei modelli sui tipi di query sono meglio predetti

# Seleziono query con iou buono per vsl net
high_iou_vslnet = df_vslnet[(df_vslnet["iou"] >=0.5)]

# Seleziono query con iou buono per vsl base
high_iou_vslbase = df_vslbase[(df_vslbase["iou"] >= 0.5)]

# Calcola conteggio query per template con IoU >= 0.5
counts_vslnet = high_iou_vslnet['template'].value_counts()
counts_vslbase = high_iou_vslbase['template'].value_counts()

# Crea un DataFrame con i conteggi
df_plot = pd.DataFrame({
    'template': counts_vslnet.index.union(counts_vslbase.index),  # Unione di tutti i template
    'VSLNet': counts_vslnet,
    'VSLBase': counts_vslbase
}).fillna(0)

# Porta in formato "long"
df_long = df_plot.melt(id_vars='template', var_name='model', value_name='count')

# Plot
plt.figure(figsize=(12, 7))
sns.barplot(data=df_long, x='count', y='template', hue='model')
plt.title("Query with IoU ≥ 0.5, group by template (VSLNet vs VSLBase)")
plt.xlabel("Number di queries")
plt.ylabel("Template")
plt.tight_layout()
plt.legend(title="Modello")
plt.show()

# %% [markdown]
# Qui osserviamo un comportamento diverso rispetto a Ominivore Bert e Glove. Infatti per alcuni tipi di query il base va meglio del Net, come State of an object, Where is object X before/ after event Y?
#
# Per EgoVLPBert questo comportamento avveniva per: When did I talk to or interact with person with role X? o Where is my object X? o In what location did I see object X?
# STRANO

# %%
# @title Blox plot finale per template
# Aggiungi una colonna 'key' a entrambi
df_vslnet["key"] = list(zip(df_vslnet["clip_uid"], df_vslnet["annotation_uid"], df_vslnet["query_idx"]))
df_vslbase["key"] = list(zip(df_vslbase["clip_uid"], df_vslbase["annotation_uid"], df_vslbase["query_idx"]))

# Costruisci DataFrame con info da entrambi
merged = pd.merge(
    df_vslnet[["key", "iou", "template"]].rename(columns={"iou": "iou_vslnet", "template": "template_vslnet"}),
    df_vslbase[["key", "iou", "template"]].rename(columns={"iou": "iou_vslbase", "template": "template_vslbase"}),
    on="key"
)

# %%
# Calcolo della media IoU per ordinare i template
media_iou = merged.groupby("template_vslnet")["iou_vslnet"].mean().sort_values(ascending=False)
ordered_templates = media_iou.index

plt.figure(figsize=(14, 7))
sns.boxplot(
    data=merged,
    x="template_vslnet",
    y="iou_vslnet",
    order=ordered_templates,
    color='lightgray',
    boxprops=dict(alpha=0.7)
)

sns.pointplot(
    data=merged,
    x="template_vslnet",
    y="iou_vslnet",
    order=ordered_templates,
    estimator='mean',
    ci=95,
    color='red',
    markers='D',
    linestyles='',
    scale=1.0,
    errwidth=1.5
)

# Aggiungi soglia
plt.axhline(0.5, color='green', linestyle='--', linewidth=1, label='IoU = 0.5')

# Etichette con numero di campioni
counts = merged['template_vslnet'].value_counts()
new_labels = [f"{t}\n(n={counts[t]})" for t in ordered_templates]
plt.xticks(ticks=range(len(new_labels)), labels=new_labels, rotation=45, ha ='right')

plt.title("Distribution of IoU VSLNet, group  by template")
plt.xlabel("Template")
plt.ylabel("IoU VSLNet")
plt.grid(True, axis='y', linestyle='--', alpha=0.5)
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-38-2941853504.py:15: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', 95)` for the same effect.
#
#   sns.pointplot(
# /tmp/ipython-input-38-2941853504.py:15: UserWarning:
#
# The `scale` parameter is deprecated and will be removed in v0.15.0. You can now control the size of each plot element using matplotlib `Line2D` parameters (e.g., `linewidth`, `markersize`, etc.).
#
#   sns.pointplot(
# /tmp/ipython-input-38-2941853504.py:15: FutureWarning:
#
# The `errwidth` parameter is deprecated. And will be removed in v0.15.0. Pass `err_kws={'linewidth': 1.5}` instead.
#
#   sns.pointplot(

# %%
# Calcolo della media IoU per ordinare i template
media_iou = merged.groupby("template_vslbase")["iou_vslbase"].mean().sort_values(ascending=False)
ordered_templates = media_iou.index

plt.figure(figsize=(14, 7))
sns.boxplot(
    data=merged,
    x="template_vslbase",
    y="iou_vslnet",
    order=ordered_templates,
    color='lightgray',
    boxprops=dict(alpha=0.7)
)

sns.pointplot(
    data=merged,
    x="template_vslnet",
    y="iou_vslnet",
    order=ordered_templates,
    estimator='mean',
    ci=95,
    color='red',
    markers='D',
    linestyles='',
    scale=1.0,
    errwidth=1.5
)

# Aggiungi soglia
plt.axhline(0.5, color='green', linestyle='--', linewidth=1, label='IoU = 0.5')

# Etichette con numero di campioni
counts = merged['template_vslnet'].value_counts()
new_labels = [f"{t}\n(n={counts[t]})" for t in ordered_templates]
plt.xticks(ticks=range(len(new_labels)), labels=new_labels, rotation=45, ha = 'right')

plt.title("Distribution of IoU VSLBase, group by template")
plt.xlabel("Template")
plt.ylabel("IoU VSLNet")
plt.grid(True, axis='y', linestyle='--', alpha=0.5)
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-39-2101868233.py:15: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', 95)` for the same effect.
#
#   sns.pointplot(
# /tmp/ipython-input-39-2101868233.py:15: UserWarning:
#
# The `scale` parameter is deprecated and will be removed in v0.15.0. You can now control the size of each plot element using matplotlib `Line2D` parameters (e.g., `linewidth`, `markersize`, etc.).
#
#   sns.pointplot(
# /tmp/ipython-input-39-2101868233.py:15: FutureWarning:
#
# The `errwidth` parameter is deprecated. And will be removed in v0.15.0. Pass `err_kws={'linewidth': 1.5}` instead.
#
#   sns.pointplot(
